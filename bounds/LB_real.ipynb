# %%
from google.colab import drive
drive.mount('/content/drive')

# %cd drive/MyDrive/ST/stargan
# Out:
# Mounted at /content/drive
# /content/drive/MyDrive/ST/stargan

# %%
import pickle
import numpy as np
from sklearn.model_selection import train_test_split
import torch
import torch.nn as nn
from torch.utils.data import DataLoader, TensorDataset
from torch.optim.lr_scheduler import LambdaLR
import torch.optim as optim
import os
import csv

seed = 2710
torch.manual_seed(seed)
torch.cuda.manual_seed(seed)
np.random.seed(seed)

# %%
class TSTRClassifier(nn.Module):
    def __init__(self, num_timesteps=128, num_channels=3, num_classes=5):
        super(TSTRClassifier, self).__init__()

        self.conv1 = nn.Conv1d(num_channels, 16, kernel_size=5, stride=1, padding=2)
        self.bn1 = nn.BatchNorm1d(16)
        self.conv2 = nn.Conv1d(16, 32, kernel_size=5, stride=1, padding=2)
        self.bn2 = nn.BatchNorm1d(32)
        self.conv3 = nn.Conv1d(32, 64, kernel_size=5, stride=1, padding=2)
        self.bn3 = nn.BatchNorm1d(64)
        self.conv4 = nn.Conv1d(64, 128, kernel_size=5, stride=1, padding=2)
        self.bn4 = nn.BatchNorm1d(128)
        self.pool = nn.MaxPool1d(kernel_size=2, stride=2)
        self.relu = nn.ReLU()
        self.dropout = nn.Dropout(p=0.25)

        self.fc_shared = nn.Linear(num_timesteps * 8, 100)

        self.fc_class = nn.Linear(100, num_classes)

    def forward(self, x):
        x = self.pool(self.relu(self.bn1(self.conv1(x))))
        x = self.pool(self.relu(self.bn2(self.conv2(x))))
        x = self.pool(self.relu(self.bn3(self.conv3(x))))
        x = self.pool(self.relu(self.bn4(self.conv4(x))))
        x = x.view(x.size(0), -1)  # Flatten
        x = self.dropout(x)
        x = self.relu(self.fc_shared(x))

        # Final output for class prediction
        class_outputs = self.fc_class(x)
        return class_outputs


def get_df_data(dataset_name, class_idx, num_train_domains):

    # Load the dataset
    with open(f'data/{dataset_name}.pkl', 'rb') as f:
        x, y, k = pickle.load(f)

    with open(f'data/{dataset_name}_fs.pkl', 'rb') as f:
        fs = pickle.load(f)

    # Filter out the samples that are used for finetuning
    x = x[fs == 0]
    y = y[fs == 0]
    k = k[fs == 0]

    x_ = x[(y == class_idx) & (k < num_train_domains)]
    y_ = y[(y == class_idx) & (k < num_train_domains)]
    k_ = k[(y == class_idx) & (k < num_train_domains)]

    return x_, y_, k_


def get_dp_data(dataset_name, class_idx, num_train_domains):

    # Load the dataset
    with open(f'data/{dataset_name}.pkl', 'rb') as f:
        x, y, k = pickle.load(f)

    with open(f'data/{dataset_name}_fs.pkl', 'rb') as f:
        fs = pickle.load(f)

    # Filter out the samples that are used for finetuning
    x = x[fs == 0]
    y = y[fs == 0]
    k = k[fs == 0]

    x_ = x[(y == class_idx) & (k >= num_train_domains)]
    y_ = y[(y == class_idx) & (k >= num_train_domains)]
    k_ = k[(y == class_idx) & (k >= num_train_domains)]

    return x_, y_, k_


def remap_labels(y):
    label_map = {clss: i for i, clss in enumerate(np.unique(y))}
    return np.array([label_map[clss] for clss in y])


def setup_training(x_tr, y_tr, x_val, y_val, batch_size=64):
    # Convert numpy arrays to torch tensors
    x_train_tensor = torch.tensor(x_tr, dtype=torch.float32)
    y_train_tensor = torch.tensor(y_tr, dtype=torch.long)
    x_val_tensor = torch.tensor(x_val, dtype=torch.float32)
    y_val_tensor = torch.tensor(y_val, dtype=torch.long)

    # Create datasets and loaders
    train_dataset = TensorDataset(x_train_tensor, y_train_tensor)
    train_loader = DataLoader(train_dataset, batch_size=batch_size, shuffle=True)
    val_dataset = TensorDataset(x_val_tensor, y_val_tensor)
    val_loader = DataLoader(val_dataset, batch_size=batch_size, shuffle=False)

    return train_loader, val_loader


def train_model(model, train_loader, val_loader, loss_fn, optimizer, epochs=300):
    device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
    model.to(device)

    loss_train = []
    loss_val = []
    accuracy_val = []
    best_loss = np.inf
    best_accuracy = 0

    # Set up linear learning rate decay
    lambda_lr = lambda epoch: 1 - epoch / epochs
    scheduler = LambdaLR(optimizer, lr_lambda=lambda_lr)

    for epoch in range(epochs):
        model.train()
        total_loss = 0
        for x_batch, y_batch in train_loader:
            x_batch, y_batch = x_batch.to(device), y_batch.to(device)
            optimizer.zero_grad()
            outputs = model(x_batch)
            loss = loss_fn(outputs, y_batch)
            loss.backward()
            optimizer.step()
            total_loss += loss.item()
        total_loss /= len(train_loader)
        loss_train.append(total_loss)

        # Update learning rate
        scheduler.step()

        val_accuracy, val_loss = evaluate_model(model, val_loader, loss_fn)
        if val_accuracy > best_accuracy:
            best_epoch = epoch
            best_accuracy = val_accuracy
            best_loss = val_loss
            best_model_state = model.state_dict().copy()
        loss_val.append(val_loss)
        accuracy_val.append(val_accuracy)

        current_lr = scheduler.get_last_lr()[0]
        print(f"Epoch {epoch + 1}/{epochs} - Train loss: {total_loss:.4f} - Val loss: {val_loss:.4f} - Val accuracy: {val_accuracy:.4f} - LR: {current_lr:.6f}")

    print(f"Best epoch: {best_epoch + 1} - Best val accuracy: {best_accuracy:.4f} - Best val loss: {best_loss:.4f}")

    return best_model_state


def evaluate_model(model, test_loader, loss_fn):
    device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
    model.to(device)
    model.eval()
    total_loss = 0
    correct_predictions = 0
    total_predictions = 0

    with torch.no_grad():
        for x_batch, y_batch in test_loader:
            x_batch, y_batch = x_batch.to(device), y_batch.to(device)
            outputs = model(x_batch)
            loss = loss_fn(outputs, y_batch)
            total_loss += loss.item()

            _, predicted_labels = torch.max(outputs, 1)
            correct_predictions += (predicted_labels == y_batch).sum().item()
            total_predictions += len(y_batch)

    total_loss /= len(test_loader)
    accuracy = correct_predictions / total_predictions

    return accuracy, total_loss


def calculate_tstr_score(x_train, y_train, x_test, y_test, k_test, source, dataset):
    assert np.array_equal(np.unique(y_train), np.unique(y_test)), "Train and test labels do not match"
    # Remap labels
    y_train = remap_labels(y_train)
    y_test = remap_labels(y_test)

    x_tr, x_val, y_tr, y_val = train_test_split(x_train, y_train, test_size=0.2, random_state=2710, stratify=y_train, shuffle=True)
    tr_loader, val_loader = setup_training(x_tr, y_tr, x_val, y_val, batch_size=64)

    model = TSTRClassifier(num_timesteps=x_train.shape[2], num_channels=x_train.shape[1], num_classes=len(np.unique(y_train)))
    loss_fn = nn.CrossEntropyLoss()
    initial_lr = 0.0001
    optimizer = optim.Adam(model.parameters(), lr=initial_lr)

    best_model_state = train_model(model, tr_loader, val_loader, loss_fn, optimizer, epochs=50)
    best_model = TSTRClassifier(num_timesteps=x_train.shape[2], num_channels=x_train.shape[1], num_classes=len(np.unique(y_train)))
    best_model.load_state_dict(best_model_state)
    acc, loss = evaluate_model_on_domains(best_model, x_test, y_test, k_test, loss_fn, source, dataset)

    return acc, loss


def evaluate_model_on_domains(best_model, x_test, y_test, k_test, loss_fn, source, dataset):
    accs = []
    losses = []
    for domain in np.unique(k_test):
        x_domain = x_test[k_test == domain]
        y_domain = y_test[k_test == domain]

        x_domain_tensor = torch.tensor(x_domain, dtype=torch.float32)
        y_domain_tensor = torch.tensor(y_domain, dtype=torch.long)
        domain_dataset = TensorDataset(x_domain_tensor, y_domain_tensor)
        domain_loader = DataLoader(domain_dataset, batch_size=64, shuffle=False)

        acc, loss = evaluate_model(best_model, domain_loader, loss_fn)
        print(f'Source: {source} - Domain: {domain} - Accuracy: {acc:.2f} - Loss: {loss:.4f}')
        save_score(acc, loss, source, domain, 'LB_real', dataset)
        accs.append(acc)
        losses.append(loss)
    return np.mean(accs), np.mean(losses)


def save_score(accuracy, loss, source, domain, name, dataset):
    eval_dir = 'bounds'
    # Ensure the directory exists
    os.makedirs(eval_dir, exist_ok=True)
    # Path to the CSV file
    file_path = os.path.join(eval_dir, f'{name}_{dataset}.csv')
    # Check if the file exists
    file_exists = os.path.exists(file_path)

    # Open the file in append mode if it exists, or write mode if it doesn't
    with open(file_path, mode='a' if file_exists else 'w', newline='') as file:
        writer = csv.writer(file)
        # If the file does not exist, write the header
        if not file_exists:
            writer.writerow(['source', 'domain', 'accuracy', 'loss'])
        # Write the data rows
        writer.writerow([source, domain, accuracy, loss])

# %%
dataset = 'realworld'

if dataset == 'realworld':
    dataset_name = 'realworld_128_3ch_4cl'
    num_df_domains = 10
    num_dp_domains = 5
    num_classes = 4
    class_names = ['WAL', 'RUN', 'CLD', 'CLU']

elif dataset == 'cwru':
    dataset_name = 'cwru_256_3ch_5cl'
    num_df_domains = 4
    num_dp_domains = 4
    num_classes = 5
    class_names = ['IR', 'Ball', 'OR_centred', 'OR_orthogonal', 'OR_opposite']

classes_dict = {clss: i for i, clss in enumerate(class_names)}

accs = []

for src_class in class_names:
    trg_classes = [clss for clss in class_names if clss != src_class]

    x_df = []
    y_df = []
    k_df = []

    x_dp = []
    y_dp = []
    k_dp = []

    for trg_class in trg_classes:
        x_df_, y_df_, k_df_ = get_df_data(dataset_name, classes_dict[trg_class], num_df_domains)
        x_dp_, y_dp_, k_dp_ = get_dp_data(dataset_name, classes_dict[trg_class], num_df_domains)

        x_df.append(x_df_)
        y_df.append(y_df_)
        k_df.append(k_df_)

        x_dp.append(x_dp_)
        y_dp.append(y_dp_)
        k_dp.append(k_dp_)

    x_df = np.concatenate(x_df, axis=0)
    y_df = np.concatenate(y_df, axis=0)
    k_df = np.concatenate(k_df, axis=0)

    x_dp = np.concatenate(x_dp, axis=0)
    y_dp = np.concatenate(y_dp, axis=0)
    k_dp = np.concatenate(k_dp, axis=0)

    acc, loss = calculate_tstr_score(x_df, y_df, x_dp, y_dp, k_dp, src_class, dataset)
    accs.append(acc)

    print(f'{src_class} -> {trg_classes}: {acc:.2f}\n\n')

print(f'Mean accuracy: {np.mean(accs):.2f}')
# Out:
# Epoch 1/50 - Train loss: 0.5190 - Val loss: 0.2824 - Val accuracy: 0.9206 - LR: 0.000098
# Epoch 2/50 - Train loss: 0.1973 - Val loss: 0.1390 - Val accuracy: 0.9594 - LR: 0.000096
# Epoch 3/50 - Train loss: 0.1418 - Val loss: 0.1099 - Val accuracy: 0.9641 - LR: 0.000094
# Epoch 4/50 - Train loss: 0.1103 - Val loss: 0.0981 - Val accuracy: 0.9707 - LR: 0.000092
# Epoch 5/50 - Train loss: 0.0950 - Val loss: 0.0902 - Val accuracy: 0.9669 - LR: 0.000090
# Epoch 6/50 - Train loss: 0.0846 - Val loss: 0.0773 - Val accuracy: 0.9764 - LR: 0.000088
# Epoch 7/50 - Train loss: 0.0744 - Val loss: 0.0714 - Val accuracy: 0.9754 - LR: 0.000086
# Epoch 8/50 - Train loss: 0.0611 - Val loss: 0.0628 - Val accuracy: 0.9735 - LR: 0.000084
# Epoch 9/50 - Train loss: 0.0542 - Val loss: 0.0610 - Val accuracy: 0.9754 - LR: 0.000082
# Epoch 10/50 - Train loss: 0.0511 - Val loss: 0.0587 - Val accuracy: 0.9754 - LR: 0.000080
# Epoch 11/50 - Train loss: 0.0487 - Val loss: 0.0510 - Val accuracy: 0.9783 - LR: 0.000078
# Epoch 12/50 - Train loss: 0.0520 - Val loss: 0.0509 - Val accuracy: 0.9802 - LR: 0.000076
# Epoch 13/50 - Train loss: 0.0347 - Val loss: 0.0510 - Val accuracy: 0.9783 - LR: 0.000074
# Epoch 14/50 - Train loss: 0.0301 - Val loss: 0.0481 - Val accuracy: 0.9811 - LR: 0.000072
# Epoch 15/50 - Train loss: 0.0372 - Val loss: 0.0485 - Val accuracy: 0.9792 - LR: 0.000070
# Epoch 16/50 - Train loss: 0.0278 - Val loss: 0.0427 - Val accuracy: 0.9783 - LR: 0.000068
# Epoch 17/50 - Train loss: 0.0233 - Val loss: 0.0445 - Val accuracy: 0.9802 - LR: 0.000066
# Epoch 18/50 - Train loss: 0.0221 - Val loss: 0.0444 - Val accuracy: 0.9802 - LR: 0.000064
# Epoch 19/50 - Train loss: 0.0220 - Val loss: 0.0449 - Val accuracy: 0.9802 - LR: 0.000062
# Epoch 20/50 - Train loss: 0.0203 - Val loss: 0.0497 - Val accuracy: 0.9783 - LR: 0.000060
# Epoch 21/50 - Train loss: 0.0192 - Val loss: 0.0452 - Val accuracy: 0.9783 - LR: 0.000058
# Epoch 22/50 - Train loss: 0.0135 - Val loss: 0.0427 - Val accuracy: 0.9811 - LR: 0.000056
# Epoch 23/50 - Train loss: 0.0135 - Val loss: 0.0422 - Val accuracy: 0.9792 - LR: 0.000054
# Epoch 24/50 - Train loss: 0.0189 - Val loss: 0.0546 - Val accuracy: 0.9849 - LR: 0.000052
# Epoch 25/50 - Train loss: 0.0226 - Val loss: 0.0408 - Val accuracy: 0.9792 - LR: 0.000050
# Epoch 26/50 - Train loss: 0.0152 - Val loss: 0.0397 - Val accuracy: 0.9802 - LR: 0.000048
# Epoch 27/50 - Train loss: 0.0129 - Val loss: 0.0414 - Val accuracy: 0.9792 - LR: 0.000046
# Epoch 28/50 - Train loss: 0.0104 - Val loss: 0.0407 - Val accuracy: 0.9792 - LR: 0.000044
# Epoch 29/50 - Train loss: 0.0088 - Val loss: 0.0437 - Val accuracy: 0.9811 - LR: 0.000042
# Epoch 30/50 - Train loss: 0.0097 - Val loss: 0.0421 - Val accuracy: 0.9830 - LR: 0.000040
# Epoch 31/50 - Train loss: 0.0115 - Val loss: 0.0419 - Val accuracy: 0.9830 - LR: 0.000038
# Epoch 32/50 - Train loss: 0.0095 - Val loss: 0.0429 - Val accuracy: 0.9811 - LR: 0.000036
# Epoch 33/50 - Train loss: 0.0094 - Val loss: 0.0401 - Val accuracy: 0.9811 - LR: 0.000034
# Epoch 34/50 - Train loss: 0.0144 - Val loss: 0.0406 - Val accuracy: 0.9820 - LR: 0.000032
# Epoch 35/50 - Train loss: 0.0087 - Val loss: 0.0421 - Val accuracy: 0.9820 - LR: 0.000030
# Epoch 36/50 - Train loss: 0.0078 - Val loss: 0.0421 - Val accuracy: 0.9839 - LR: 0.000028
# Epoch 37/50 - Train loss: 0.0097 - Val loss: 0.0433 - Val accuracy: 0.9802 - LR: 0.000026
# Epoch 38/50 - Train loss: 0.0079 - Val loss: 0.0446 - Val accuracy: 0.9811 - LR: 0.000024
# Epoch 39/50 - Train loss: 0.0063 - Val loss: 0.0394 - Val accuracy: 0.9811 - LR: 0.000022
# Epoch 40/50 - Train loss: 0.0089 - Val loss: 0.0405 - Val accuracy: 0.9792 - LR: 0.000020
# Epoch 41/50 - Train loss: 0.0070 - Val loss: 0.0403 - Val accuracy: 0.9811 - LR: 0.000018
# Epoch 42/50 - Train loss: 0.0098 - Val loss: 0.0437 - Val accuracy: 0.9811 - LR: 0.000016
# Epoch 43/50 - Train loss: 0.0088 - Val loss: 0.0399 - Val accuracy: 0.9811 - LR: 0.000014
# Epoch 44/50 - Train loss: 0.0178 - Val loss: 0.0406 - Val accuracy: 0.9849 - LR: 0.000012
# Epoch 45/50 - Train loss: 0.0076 - Val loss: 0.0423 - Val accuracy: 0.9839 - LR: 0.000010
# Epoch 46/50 - Train loss: 0.0057 - Val loss: 0.0409 - Val accuracy: 0.9802 - LR: 0.000008
# Epoch 47/50 - Train loss: 0.0062 - Val loss: 0.0407 - Val accuracy: 0.9811 - LR: 0.000006
# Epoch 48/50 - Train loss: 0.0093 - Val loss: 0.0422 - Val accuracy: 0.9839 - LR: 0.000004
# Epoch 49/50 - Train loss: 0.0063 - Val loss: 0.0391 - Val accuracy: 0.9820 - LR: 0.000002
# Epoch 50/50 - Train loss: 0.0065 - Val loss: 0.0405 - Val accuracy: 0.9802 - LR: 0.000000
# Best epoch: 24 - Best val accuracy: 0.9849 - Best val loss: 0.0546
# Source: WAL - Domain: 10 - Accuracy: 0.97 - Loss: 0.0936
# Source: WAL - Domain: 11 - Accuracy: 0.96 - Loss: 0.1407
# Source: WAL - Domain: 12 - Accuracy: 0.95 - Loss: 0.1079
# Source: WAL - Domain: 13 - Accuracy: 0.95 - Loss: 0.0934
# Source: WAL - Domain: 14 - Accuracy: 0.96 - Loss: 0.1338
# WAL -> ['RUN', 'CLD', 'CLU']: 0.96
#
#
# Epoch 1/50 - Train loss: 0.8059 - Val loss: 0.6512 - Val accuracy: 0.7338 - LR: 0.000098
# Epoch 2/50 - Train loss: 0.4300 - Val loss: 0.3425 - Val accuracy: 0.8881 - LR: 0.000096
# Epoch 3/50 - Train loss: 0.2879 - Val loss: 0.2768 - Val accuracy: 0.9043 - LR: 0.000094
# Epoch 4/50 - Train loss: 0.2399 - Val loss: 0.2396 - Val accuracy: 0.9206 - LR: 0.000092
# Epoch 5/50 - Train loss: 0.1981 - Val loss: 0.2042 - Val accuracy: 0.9341 - LR: 0.000090
# Epoch 6/50 - Train loss: 0.1761 - Val loss: 0.1889 - Val accuracy: 0.9368 - LR: 0.000088
# Epoch 7/50 - Train loss: 0.1497 - Val loss: 0.1767 - Val accuracy: 0.9359 - LR: 0.000086
# Epoch 8/50 - Train loss: 0.1431 - Val loss: 0.1717 - Val accuracy: 0.9422 - LR: 0.000084
# Epoch 9/50 - Train loss: 0.1261 - Val loss: 0.2163 - Val accuracy: 0.9269 - LR: 0.000082
# Epoch 10/50 - Train loss: 0.1089 - Val loss: 0.1723 - Val accuracy: 0.9413 - LR: 0.000080
# Epoch 11/50 - Train loss: 0.0998 - Val loss: 0.1716 - Val accuracy: 0.9468 - LR: 0.000078
# Epoch 12/50 - Train loss: 0.0892 - Val loss: 0.1700 - Val accuracy: 0.9486 - LR: 0.000076
# Epoch 13/50 - Train loss: 0.0816 - Val loss: 0.1571 - Val accuracy: 0.9477 - LR: 0.000074
# Epoch 14/50 - Train loss: 0.0808 - Val loss: 0.1552 - Val accuracy: 0.9486 - LR: 0.000072
# Epoch 15/50 - Train loss: 0.0687 - Val loss: 0.1460 - Val accuracy: 0.9486 - LR: 0.000070
# Epoch 16/50 - Train loss: 0.0621 - Val loss: 0.1565 - Val accuracy: 0.9422 - LR: 0.000068
# Epoch 17/50 - Train loss: 0.0573 - Val loss: 0.1523 - Val accuracy: 0.9395 - LR: 0.000066
# Epoch 18/50 - Train loss: 0.0514 - Val loss: 0.1462 - Val accuracy: 0.9477 - LR: 0.000064
# Epoch 19/50 - Train loss: 0.0463 - Val loss: 0.1505 - Val accuracy: 0.9449 - LR: 0.000062
# Epoch 20/50 - Train loss: 0.0424 - Val loss: 0.1649 - Val accuracy: 0.9449 - LR: 0.000060
# Epoch 21/50 - Train loss: 0.0410 - Val loss: 0.1536 - Val accuracy: 0.9486 - LR: 0.000058
# Epoch 22/50 - Train loss: 0.0357 - Val loss: 0.1435 - Val accuracy: 0.9522 - LR: 0.000056
# Epoch 23/50 - Train loss: 0.0320 - Val loss: 0.1479 - Val accuracy: 0.9477 - LR: 0.000054
# Epoch 24/50 - Train loss: 0.0310 - Val loss: 0.1532 - Val accuracy: 0.9540 - LR: 0.000052
# Epoch 25/50 - Train loss: 0.0309 - Val loss: 0.1393 - Val accuracy: 0.9477 - LR: 0.000050
# Epoch 26/50 - Train loss: 0.0266 - Val loss: 0.1514 - Val accuracy: 0.9504 - LR: 0.000048
# Epoch 27/50 - Train loss: 0.0301 - Val loss: 0.1567 - Val accuracy: 0.9504 - LR: 0.000046
# Epoch 28/50 - Train loss: 0.0281 - Val loss: 0.1714 - Val accuracy: 0.9522 - LR: 0.000044
# Epoch 29/50 - Train loss: 0.0236 - Val loss: 0.1466 - Val accuracy: 0.9495 - LR: 0.000042
# Epoch 30/50 - Train loss: 0.0191 - Val loss: 0.1452 - Val accuracy: 0.9513 - LR: 0.000040
# Epoch 31/50 - Train loss: 0.0242 - Val loss: 0.1502 - Val accuracy: 0.9522 - LR: 0.000038
# Epoch 32/50 - Train loss: 0.0176 - Val loss: 0.1482 - Val accuracy: 0.9513 - LR: 0.000036
# Epoch 33/50 - Train loss: 0.0192 - Val loss: 0.1509 - Val accuracy: 0.9549 - LR: 0.000034
# Epoch 34/50 - Train loss: 0.0173 - Val loss: 0.1645 - Val accuracy: 0.9531 - LR: 0.000032
# Epoch 35/50 - Train loss: 0.0197 - Val loss: 0.1571 - Val accuracy: 0.9468 - LR: 0.000030
# Epoch 36/50 - Train loss: 0.0148 - Val loss: 0.1584 - Val accuracy: 0.9549 - LR: 0.000028
# Epoch 37/50 - Train loss: 0.0161 - Val loss: 0.1527 - Val accuracy: 0.9513 - LR: 0.000026
# Epoch 38/50 - Train loss: 0.0158 - Val loss: 0.1718 - Val accuracy: 0.9540 - LR: 0.000024
# Epoch 39/50 - Train loss: 0.0155 - Val loss: 0.1493 - Val accuracy: 0.9549 - LR: 0.000022
# Epoch 40/50 - Train loss: 0.0145 - Val loss: 0.1562 - Val accuracy: 0.9504 - LR: 0.000020
# Epoch 41/50 - Train loss: 0.0134 - Val loss: 0.1579 - Val accuracy: 0.9540 - LR: 0.000018
# Epoch 42/50 - Train loss: 0.0149 - Val loss: 0.1528 - Val accuracy: 0.9531 - LR: 0.000016
# Epoch 43/50 - Train loss: 0.0161 - Val loss: 0.1579 - Val accuracy: 0.9513 - LR: 0.000014
# Epoch 44/50 - Train loss: 0.0131 - Val loss: 0.1595 - Val accuracy: 0.9540 - LR: 0.000012
# Epoch 45/50 - Train loss: 0.0120 - Val loss: 0.1529 - Val accuracy: 0.9531 - LR: 0.000010
# Epoch 46/50 - Train loss: 0.0135 - Val loss: 0.1548 - Val accuracy: 0.9540 - LR: 0.000008
# Epoch 47/50 - Train loss: 0.0123 - Val loss: 0.1545 - Val accuracy: 0.9495 - LR: 0.000006
# Epoch 48/50 - Train loss: 0.0132 - Val loss: 0.1547 - Val accuracy: 0.9531 - LR: 0.000004
# Epoch 49/50 - Train loss: 0.0143 - Val loss: 0.1559 - Val accuracy: 0.9513 - LR: 0.000002
# Epoch 50/50 - Train loss: 0.0135 - Val loss: 0.1580 - Val accuracy: 0.9558 - LR: 0.000000
# Best epoch: 50 - Best val accuracy: 0.9558 - Best val loss: 0.1580
# Source: RUN - Domain: 10 - Accuracy: 0.78 - Loss: 0.7185
# Source: RUN - Domain: 11 - Accuracy: 0.89 - Loss: 0.3429
# Source: RUN - Domain: 12 - Accuracy: 0.78 - Loss: 0.7232
# Source: RUN - Domain: 13 - Accuracy: 0.87 - Loss: 0.4742
# Source: RUN - Domain: 14 - Accuracy: 0.73 - Loss: 0.7641
# RUN -> ['WAL', 'CLD', 'CLU']: 0.81
#
#
# Epoch 1/50 - Train loss: 0.4643 - Val loss: 0.2713 - Val accuracy: 0.8997 - LR: 0.000098
# Epoch 2/50 - Train loss: 0.2105 - Val loss: 0.1513 - Val accuracy: 0.9527 - LR: 0.000096
# Epoch 3/50 - Train loss: 0.1359 - Val loss: 0.1207 - Val accuracy: 0.9641 - LR: 0.000094
# Epoch 4/50 - Train loss: 0.1136 - Val loss: 0.1026 - Val accuracy: 0.9706 - LR: 0.000092
# Epoch 5/50 - Train loss: 0.0992 - Val loss: 0.0965 - Val accuracy: 0.9715 - LR: 0.000090
# Epoch 6/50 - Train loss: 0.0847 - Val loss: 0.0938 - Val accuracy: 0.9715 - LR: 0.000088
# Epoch 7/50 - Train loss: 0.0741 - Val loss: 0.0883 - Val accuracy: 0.9723 - LR: 0.000086
# Epoch 8/50 - Train loss: 0.0662 - Val loss: 0.0885 - Val accuracy: 0.9723 - LR: 0.000084
# Epoch 9/50 - Train loss: 0.0600 - Val loss: 0.0821 - Val accuracy: 0.9755 - LR: 0.000082
# Epoch 10/50 - Train loss: 0.0600 - Val loss: 0.0764 - Val accuracy: 0.9763 - LR: 0.000080
# Epoch 11/50 - Train loss: 0.0538 - Val loss: 0.0800 - Val accuracy: 0.9772 - LR: 0.000078
# Epoch 12/50 - Train loss: 0.0455 - Val loss: 0.0788 - Val accuracy: 0.9763 - LR: 0.000076
# Epoch 13/50 - Train loss: 0.0429 - Val loss: 0.0741 - Val accuracy: 0.9772 - LR: 0.000074
# Epoch 14/50 - Train loss: 0.0403 - Val loss: 0.0772 - Val accuracy: 0.9788 - LR: 0.000072
# Epoch 15/50 - Train loss: 0.0338 - Val loss: 0.0703 - Val accuracy: 0.9780 - LR: 0.000070
# Epoch 16/50 - Train loss: 0.0335 - Val loss: 0.0767 - Val accuracy: 0.9788 - LR: 0.000068
# Epoch 17/50 - Train loss: 0.0284 - Val loss: 0.0684 - Val accuracy: 0.9788 - LR: 0.000066
# Epoch 18/50 - Train loss: 0.0265 - Val loss: 0.0714 - Val accuracy: 0.9796 - LR: 0.000064
# Epoch 19/50 - Train loss: 0.0239 - Val loss: 0.0730 - Val accuracy: 0.9788 - LR: 0.000062
# Epoch 20/50 - Train loss: 0.0227 - Val loss: 0.0711 - Val accuracy: 0.9788 - LR: 0.000060
# Epoch 21/50 - Train loss: 0.0164 - Val loss: 0.0726 - Val accuracy: 0.9788 - LR: 0.000058
# Epoch 22/50 - Train loss: 0.0193 - Val loss: 0.0771 - Val accuracy: 0.9796 - LR: 0.000056
# Epoch 23/50 - Train loss: 0.0180 - Val loss: 0.0718 - Val accuracy: 0.9796 - LR: 0.000054
# Epoch 24/50 - Train loss: 0.0180 - Val loss: 0.0715 - Val accuracy: 0.9804 - LR: 0.000052
# Epoch 25/50 - Train loss: 0.0234 - Val loss: 0.0762 - Val accuracy: 0.9780 - LR: 0.000050
# Epoch 26/50 - Train loss: 0.0137 - Val loss: 0.0678 - Val accuracy: 0.9796 - LR: 0.000048
# Epoch 27/50 - Train loss: 0.0146 - Val loss: 0.0659 - Val accuracy: 0.9829 - LR: 0.000046
# Epoch 28/50 - Train loss: 0.0110 - Val loss: 0.0759 - Val accuracy: 0.9796 - LR: 0.000044
# Epoch 29/50 - Train loss: 0.0115 - Val loss: 0.0725 - Val accuracy: 0.9812 - LR: 0.000042
# Epoch 30/50 - Train loss: 0.0133 - Val loss: 0.0826 - Val accuracy: 0.9780 - LR: 0.000040
# Epoch 31/50 - Train loss: 0.0106 - Val loss: 0.0665 - Val accuracy: 0.9829 - LR: 0.000038
# Epoch 32/50 - Train loss: 0.0086 - Val loss: 0.0695 - Val accuracy: 0.9837 - LR: 0.000036
# Epoch 33/50 - Train loss: 0.0133 - Val loss: 0.0688 - Val accuracy: 0.9837 - LR: 0.000034
# Epoch 34/50 - Train loss: 0.0079 - Val loss: 0.0719 - Val accuracy: 0.9812 - LR: 0.000032
# Epoch 35/50 - Train loss: 0.0077 - Val loss: 0.0751 - Val accuracy: 0.9812 - LR: 0.000030
# Epoch 36/50 - Train loss: 0.0078 - Val loss: 0.0701 - Val accuracy: 0.9829 - LR: 0.000028
# Epoch 37/50 - Train loss: 0.0068 - Val loss: 0.0756 - Val accuracy: 0.9812 - LR: 0.000026
# Epoch 38/50 - Train loss: 0.0090 - Val loss: 0.0761 - Val accuracy: 0.9829 - LR: 0.000024
# Epoch 39/50 - Train loss: 0.0068 - Val loss: 0.0716 - Val accuracy: 0.9829 - LR: 0.000022
# Epoch 40/50 - Train loss: 0.0057 - Val loss: 0.0716 - Val accuracy: 0.9821 - LR: 0.000020
# Epoch 41/50 - Train loss: 0.0051 - Val loss: 0.0767 - Val accuracy: 0.9804 - LR: 0.000018
# Epoch 42/50 - Train loss: 0.0067 - Val loss: 0.0766 - Val accuracy: 0.9821 - LR: 0.000016
# Epoch 43/50 - Train loss: 0.0051 - Val loss: 0.0740 - Val accuracy: 0.9829 - LR: 0.000014
# Epoch 44/50 - Train loss: 0.0064 - Val loss: 0.0710 - Val accuracy: 0.9837 - LR: 0.000012
# Epoch 45/50 - Train loss: 0.0048 - Val loss: 0.0729 - Val accuracy: 0.9821 - LR: 0.000010
# Epoch 46/50 - Train loss: 0.0067 - Val loss: 0.0791 - Val accuracy: 0.9812 - LR: 0.000008
# Epoch 47/50 - Train loss: 0.0054 - Val loss: 0.0754 - Val accuracy: 0.9812 - LR: 0.000006
# Epoch 48/50 - Train loss: 0.0046 - Val loss: 0.0771 - Val accuracy: 0.9821 - LR: 0.000004
# Epoch 49/50 - Train loss: 0.0053 - Val loss: 0.0752 - Val accuracy: 0.9837 - LR: 0.000002
# Epoch 50/50 - Train loss: 0.0045 - Val loss: 0.0787 - Val accuracy: 0.9812 - LR: 0.000000
# Best epoch: 32 - Best val accuracy: 0.9837 - Best val loss: 0.0695
# Source: CLD - Domain: 10 - Accuracy: 0.90 - Loss: 0.3117
# Source: CLD - Domain: 11 - Accuracy: 0.95 - Loss: 0.1935
# Source: CLD - Domain: 12 - Accuracy: 0.89 - Loss: 0.4421
# Source: CLD - Domain: 13 - Accuracy: 0.98 - Loss: 0.0563
# Source: CLD - Domain: 14 - Accuracy: 0.74 - Loss: 0.9204
# CLD -> ['WAL', 'RUN', 'CLU']: 0.89
#
#
# Epoch 1/50 - Train loss: 0.5475 - Val loss: 0.3419 - Val accuracy: 0.8966 - LR: 0.000098
# Epoch 2/50 - Train loss: 0.2413 - Val loss: 0.1838 - Val accuracy: 0.9441 - LR: 0.000096
# Epoch 3/50 - Train loss: 0.1522 - Val loss: 0.1388 - Val accuracy: 0.9542 - LR: 0.000094
# Epoch 4/50 - Train loss: 0.1152 - Val loss: 0.1136 - Val accuracy: 0.9602 - LR: 0.000092
# Epoch 5/50 - Train loss: 0.1044 - Val loss: 0.0948 - Val accuracy: 0.9686 - LR: 0.000090
# Epoch 6/50 - Train loss: 0.0825 - Val loss: 0.0965 - Val accuracy: 0.9669 - LR: 0.000088
# Epoch 7/50 - Train loss: 0.0717 - Val loss: 0.0867 - Val accuracy: 0.9729 - LR: 0.000086
# Epoch 8/50 - Train loss: 0.0746 - Val loss: 0.0790 - Val accuracy: 0.9729 - LR: 0.000084
# Epoch 9/50 - Train loss: 0.0600 - Val loss: 0.0767 - Val accuracy: 0.9712 - LR: 0.000082
# Epoch 10/50 - Train loss: 0.0570 - Val loss: 0.0727 - Val accuracy: 0.9737 - LR: 0.000080
# Epoch 11/50 - Train loss: 0.0523 - Val loss: 0.0747 - Val accuracy: 0.9746 - LR: 0.000078
# Epoch 12/50 - Train loss: 0.0471 - Val loss: 0.0741 - Val accuracy: 0.9754 - LR: 0.000076
# Epoch 13/50 - Train loss: 0.0424 - Val loss: 0.0660 - Val accuracy: 0.9763 - LR: 0.000074
# Epoch 14/50 - Train loss: 0.0363 - Val loss: 0.0654 - Val accuracy: 0.9763 - LR: 0.000072
# Epoch 15/50 - Train loss: 0.0311 - Val loss: 0.0684 - Val accuracy: 0.9771 - LR: 0.000070
# Epoch 16/50 - Train loss: 0.0296 - Val loss: 0.0733 - Val accuracy: 0.9771 - LR: 0.000068
# Epoch 17/50 - Train loss: 0.0274 - Val loss: 0.0649 - Val accuracy: 0.9763 - LR: 0.000066
# Epoch 18/50 - Train loss: 0.0254 - Val loss: 0.0651 - Val accuracy: 0.9788 - LR: 0.000064
# Epoch 19/50 - Train loss: 0.0227 - Val loss: 0.0618 - Val accuracy: 0.9771 - LR: 0.000062
# Epoch 20/50 - Train loss: 0.0201 - Val loss: 0.0657 - Val accuracy: 0.9771 - LR: 0.000060
# Epoch 21/50 - Train loss: 0.0182 - Val loss: 0.0601 - Val accuracy: 0.9814 - LR: 0.000058
# Epoch 22/50 - Train loss: 0.0157 - Val loss: 0.0598 - Val accuracy: 0.9805 - LR: 0.000056
# Epoch 23/50 - Train loss: 0.0157 - Val loss: 0.0633 - Val accuracy: 0.9805 - LR: 0.000054
# Epoch 24/50 - Train loss: 0.0142 - Val loss: 0.0742 - Val accuracy: 0.9788 - LR: 0.000052
# Epoch 25/50 - Train loss: 0.0109 - Val loss: 0.0654 - Val accuracy: 0.9780 - LR: 0.000050
# Epoch 26/50 - Train loss: 0.0130 - Val loss: 0.0615 - Val accuracy: 0.9805 - LR: 0.000048
# Epoch 27/50 - Train loss: 0.0115 - Val loss: 0.0653 - Val accuracy: 0.9805 - LR: 0.000046
# Epoch 28/50 - Train loss: 0.0117 - Val loss: 0.0650 - Val accuracy: 0.9814 - LR: 0.000044
# Epoch 29/50 - Train loss: 0.0086 - Val loss: 0.0653 - Val accuracy: 0.9805 - LR: 0.000042
# Epoch 30/50 - Train loss: 0.0079 - Val loss: 0.0691 - Val accuracy: 0.9814 - LR: 0.000040
# Epoch 31/50 - Train loss: 0.0103 - Val loss: 0.0662 - Val accuracy: 0.9822 - LR: 0.000038
# Epoch 32/50 - Train loss: 0.0070 - Val loss: 0.0651 - Val accuracy: 0.9805 - LR: 0.000036
# Epoch 33/50 - Train loss: 0.0078 - Val loss: 0.0634 - Val accuracy: 0.9814 - LR: 0.000034
# Epoch 34/50 - Train loss: 0.0063 - Val loss: 0.0671 - Val accuracy: 0.9822 - LR: 0.000032
# Epoch 35/50 - Train loss: 0.0064 - Val loss: 0.0639 - Val accuracy: 0.9814 - LR: 0.000030
# Epoch 36/50 - Train loss: 0.0049 - Val loss: 0.0653 - Val accuracy: 0.9814 - LR: 0.000028
# Epoch 37/50 - Train loss: 0.0066 - Val loss: 0.0624 - Val accuracy: 0.9814 - LR: 0.000026
# Epoch 38/50 - Train loss: 0.0055 - Val loss: 0.0683 - Val accuracy: 0.9822 - LR: 0.000024
# Epoch 39/50 - Train loss: 0.0056 - Val loss: 0.0692 - Val accuracy: 0.9814 - LR: 0.000022
# Epoch 40/50 - Train loss: 0.0055 - Val loss: 0.0653 - Val accuracy: 0.9814 - LR: 0.000020
# Epoch 41/50 - Train loss: 0.0043 - Val loss: 0.0671 - Val accuracy: 0.9805 - LR: 0.000018
# Epoch 42/50 - Train loss: 0.0046 - Val loss: 0.0645 - Val accuracy: 0.9814 - LR: 0.000016
# Epoch 43/50 - Train loss: 0.0041 - Val loss: 0.0673 - Val accuracy: 0.9805 - LR: 0.000014
# Epoch 44/50 - Train loss: 0.0043 - Val loss: 0.0685 - Val accuracy: 0.9814 - LR: 0.000012
# Epoch 45/50 - Train loss: 0.0053 - Val loss: 0.0689 - Val accuracy: 0.9822 - LR: 0.000010
# Epoch 46/50 - Train loss: 0.0043 - Val loss: 0.0670 - Val accuracy: 0.9814 - LR: 0.000008
# Epoch 47/50 - Train loss: 0.0039 - Val loss: 0.0679 - Val accuracy: 0.9805 - LR: 0.000006
# Epoch 48/50 - Train loss: 0.0035 - Val loss: 0.0662 - Val accuracy: 0.9814 - LR: 0.000004
# Epoch 49/50 - Train loss: 0.0038 - Val loss: 0.0659 - Val accuracy: 0.9814 - LR: 0.000002
# Epoch 50/50 - Train loss: 0.0036 - Val loss: 0.0673 - Val accuracy: 0.9814 - LR: 0.000000
# Best epoch: 31 - Best val accuracy: 0.9822 - Best val loss: 0.0662
# Source: CLU - Domain: 10 - Accuracy: 0.89 - Loss: 0.3694
# Source: CLU - Domain: 11 - Accuracy: 0.96 - Loss: 0.2049
# Source: CLU - Domain: 12 - Accuracy: 0.91 - Loss: 0.2738
# Source: CLU - Domain: 13 - Accuracy: 0.99 - Loss: 0.0331
# Source: CLU - Domain: 14 - Accuracy: 0.61 - Loss: 1.9847
# CLU -> ['WAL', 'RUN', 'CLD']: 0.87
#
#
# Mean accuracy: 0.88

# %%
dataset = 'cwru'

if dataset == 'realworld':
    dataset_name = 'realworld_128_3ch_4cl'
    num_df_domains = 10
    num_dp_domains = 5
    num_classes = 4
    class_names = ['WAL', 'RUN', 'CLD', 'CLU']

elif dataset == 'cwru':
    dataset_name = 'cwru_256_3ch_5cl'
    num_df_domains = 4
    num_dp_domains = 4
    num_classes = 5
    class_names = ['IR', 'Ball', 'OR_centred', 'OR_orthogonal', 'OR_opposite']

classes_dict = {clss: i for i, clss in enumerate(class_names)}

accs = []

for src_class in class_names:
    trg_classes = [clss for clss in class_names if clss != src_class]

    x_df = []
    y_df = []
    k_df = []

    x_dp = []
    y_dp = []
    k_dp = []

    for trg_class in trg_classes:
        x_df_, y_df_, k_df_ = get_df_data(dataset_name, classes_dict[trg_class], num_df_domains)
        x_dp_, y_dp_, k_dp_ = get_dp_data(dataset_name, classes_dict[trg_class], num_df_domains)

        x_df.append(x_df_)
        y_df.append(y_df_)
        k_df.append(k_df_)

        x_dp.append(x_dp_)
        y_dp.append(y_dp_)
        k_dp.append(k_dp_)

    x_df = np.concatenate(x_df, axis=0)
    y_df = np.concatenate(y_df, axis=0)
    k_df = np.concatenate(k_df, axis=0)

    x_dp = np.concatenate(x_dp, axis=0)
    y_dp = np.concatenate(y_dp, axis=0)
    k_dp = np.concatenate(k_dp, axis=0)

    acc, loss = calculate_tstr_score(x_df, y_df, x_dp, y_dp, k_dp, src_class, dataset)
    accs.append(acc)

    print(f'{src_class} -> {trg_classes}: {acc:.2f}\n\n')

print(f'Mean accuracy: {np.mean(accs):.2f}')
# Out:
# Epoch 1/50 - Train loss: 0.4641 - Val loss: 0.1536 - Val accuracy: 0.9794 - LR: 0.000098
# Epoch 2/50 - Train loss: 0.0871 - Val loss: 0.9108 - Val accuracy: 0.7440 - LR: 0.000096
# Epoch 3/50 - Train loss: 0.0380 - Val loss: 0.0285 - Val accuracy: 0.9894 - LR: 0.000094
# Epoch 4/50 - Train loss: 0.0243 - Val loss: 0.0634 - Val accuracy: 0.9814 - LR: 0.000092
# Epoch 5/50 - Train loss: 0.0109 - Val loss: 0.0044 - Val accuracy: 0.9993 - LR: 0.000090
# Epoch 6/50 - Train loss: 0.0111 - Val loss: 0.0041 - Val accuracy: 0.9993 - LR: 0.000088
# Epoch 7/50 - Train loss: 0.0083 - Val loss: 0.0028 - Val accuracy: 0.9993 - LR: 0.000086
# Epoch 8/50 - Train loss: 0.0053 - Val loss: 0.0051 - Val accuracy: 0.9987 - LR: 0.000084
# Epoch 9/50 - Train loss: 0.0046 - Val loss: 0.0019 - Val accuracy: 1.0000 - LR: 0.000082
# Epoch 10/50 - Train loss: 0.0044 - Val loss: 0.0029 - Val accuracy: 1.0000 - LR: 0.000080
# Epoch 11/50 - Train loss: 0.0032 - Val loss: 0.0016 - Val accuracy: 0.9993 - LR: 0.000078
# Epoch 12/50 - Train loss: 0.0026 - Val loss: 0.0032 - Val accuracy: 0.9993 - LR: 0.000076
# Epoch 13/50 - Train loss: 0.0023 - Val loss: 0.0019 - Val accuracy: 0.9993 - LR: 0.000074
# Epoch 14/50 - Train loss: 0.0016 - Val loss: 0.0015 - Val accuracy: 1.0000 - LR: 0.000072
# Epoch 15/50 - Train loss: 0.0018 - Val loss: 0.0026 - Val accuracy: 0.9993 - LR: 0.000070
# Epoch 16/50 - Train loss: 0.0030 - Val loss: 0.0867 - Val accuracy: 0.9695 - LR: 0.000068
# Epoch 17/50 - Train loss: 0.0041 - Val loss: 0.0009 - Val accuracy: 0.9993 - LR: 0.000066
# Epoch 18/50 - Train loss: 0.0036 - Val loss: 0.0011 - Val accuracy: 0.9993 - LR: 0.000064
# Epoch 19/50 - Train loss: 0.0015 - Val loss: 0.0010 - Val accuracy: 1.0000 - LR: 0.000062
# Epoch 20/50 - Train loss: 0.0037 - Val loss: 0.0006 - Val accuracy: 1.0000 - LR: 0.000060
# Epoch 21/50 - Train loss: 0.0020 - Val loss: 0.0014 - Val accuracy: 1.0000 - LR: 0.000058
# Epoch 22/50 - Train loss: 0.0017 - Val loss: 0.0005 - Val accuracy: 1.0000 - LR: 0.000056
# Epoch 23/50 - Train loss: 0.0011 - Val loss: 0.0007 - Val accuracy: 1.0000 - LR: 0.000054
# Epoch 24/50 - Train loss: 0.0006 - Val loss: 0.0005 - Val accuracy: 1.0000 - LR: 0.000052
# Epoch 25/50 - Train loss: 0.0006 - Val loss: 0.0007 - Val accuracy: 0.9993 - LR: 0.000050
# Epoch 26/50 - Train loss: 0.0012 - Val loss: 0.0005 - Val accuracy: 1.0000 - LR: 0.000048
# Epoch 27/50 - Train loss: 0.0007 - Val loss: 0.0004 - Val accuracy: 1.0000 - LR: 0.000046
# Epoch 28/50 - Train loss: 0.0008 - Val loss: 0.0004 - Val accuracy: 1.0000 - LR: 0.000044
# Epoch 29/50 - Train loss: 0.0015 - Val loss: 0.0003 - Val accuracy: 1.0000 - LR: 0.000042
# Epoch 30/50 - Train loss: 0.0005 - Val loss: 0.0010 - Val accuracy: 0.9993 - LR: 0.000040
# Epoch 31/50 - Train loss: 0.0007 - Val loss: 0.0006 - Val accuracy: 1.0000 - LR: 0.000038
# Epoch 32/50 - Train loss: 0.0004 - Val loss: 0.0005 - Val accuracy: 1.0000 - LR: 0.000036
# Epoch 33/50 - Train loss: 0.0014 - Val loss: 0.0065 - Val accuracy: 0.9973 - LR: 0.000034
# Epoch 34/50 - Train loss: 0.0007 - Val loss: 0.0014 - Val accuracy: 0.9993 - LR: 0.000032
# Epoch 35/50 - Train loss: 0.0006 - Val loss: 0.0003 - Val accuracy: 1.0000 - LR: 0.000030
# Epoch 36/50 - Train loss: 0.0002 - Val loss: 0.0003 - Val accuracy: 1.0000 - LR: 0.000028
# Epoch 37/50 - Train loss: 0.0055 - Val loss: 0.0017 - Val accuracy: 0.9993 - LR: 0.000026
# Epoch 38/50 - Train loss: 0.0042 - Val loss: 0.0008 - Val accuracy: 0.9993 - LR: 0.000024
# Epoch 39/50 - Train loss: 0.0015 - Val loss: 0.0005 - Val accuracy: 1.0000 - LR: 0.000022
# Epoch 40/50 - Train loss: 0.0004 - Val loss: 0.0004 - Val accuracy: 1.0000 - LR: 0.000020
# Epoch 41/50 - Train loss: 0.0003 - Val loss: 0.0006 - Val accuracy: 1.0000 - LR: 0.000018
# Epoch 42/50 - Train loss: 0.0003 - Val loss: 0.0007 - Val accuracy: 0.9993 - LR: 0.000016
# Epoch 43/50 - Train loss: 0.0005 - Val loss: 0.0003 - Val accuracy: 1.0000 - LR: 0.000014
# Epoch 44/50 - Train loss: 0.0004 - Val loss: 0.0005 - Val accuracy: 1.0000 - LR: 0.000012
# Epoch 45/50 - Train loss: 0.0014 - Val loss: 0.0006 - Val accuracy: 0.9993 - LR: 0.000010
# Epoch 46/50 - Train loss: 0.0005 - Val loss: 0.0004 - Val accuracy: 1.0000 - LR: 0.000008
# Epoch 47/50 - Train loss: 0.0008 - Val loss: 0.0004 - Val accuracy: 1.0000 - LR: 0.000006
# Epoch 48/50 - Train loss: 0.0003 - Val loss: 0.0006 - Val accuracy: 1.0000 - LR: 0.000004
# Epoch 49/50 - Train loss: 0.0004 - Val loss: 0.0004 - Val accuracy: 1.0000 - LR: 0.000002
# Epoch 50/50 - Train loss: 0.0004 - Val loss: 0.0006 - Val accuracy: 0.9993 - LR: 0.000000
# Best epoch: 9 - Best val accuracy: 1.0000 - Best val loss: 0.0019
# Source: IR - Domain: 4 - Accuracy: 0.46 - Loss: 3.7004
# Source: IR - Domain: 5 - Accuracy: 0.46 - Loss: 3.2972
# Source: IR - Domain: 6 - Accuracy: 0.48 - Loss: 2.9292
# Source: IR - Domain: 7 - Accuracy: 0.48 - Loss: 2.8680
# IR -> ['Ball', 'OR_centred', 'OR_orthogonal', 'OR_opposite']: 0.47
#
#
# Epoch 1/50 - Train loss: 0.4496 - Val loss: 0.0447 - Val accuracy: 1.0000 - LR: 0.000098
# Epoch 2/50 - Train loss: 0.0222 - Val loss: 0.0082 - Val accuracy: 1.0000 - LR: 0.000096
# Epoch 3/50 - Train loss: 0.0080 - Val loss: 0.0035 - Val accuracy: 1.0000 - LR: 0.000094
# Epoch 4/50 - Train loss: 0.0040 - Val loss: 0.0022 - Val accuracy: 1.0000 - LR: 0.000092
# Epoch 5/50 - Train loss: 0.0028 - Val loss: 0.0014 - Val accuracy: 1.0000 - LR: 0.000090
# Epoch 6/50 - Train loss: 0.0018 - Val loss: 0.0010 - Val accuracy: 1.0000 - LR: 0.000088
# Epoch 7/50 - Train loss: 0.0014 - Val loss: 0.0005 - Val accuracy: 1.0000 - LR: 0.000086
# Epoch 8/50 - Train loss: 0.0008 - Val loss: 0.0003 - Val accuracy: 1.0000 - LR: 0.000084
# Epoch 9/50 - Train loss: 0.0005 - Val loss: 0.0003 - Val accuracy: 1.0000 - LR: 0.000082
# Epoch 10/50 - Train loss: 0.0006 - Val loss: 0.0003 - Val accuracy: 1.0000 - LR: 0.000080
# Epoch 11/50 - Train loss: 0.0006 - Val loss: 0.0003 - Val accuracy: 1.0000 - LR: 0.000078
# Epoch 12/50 - Train loss: 0.0004 - Val loss: 0.0002 - Val accuracy: 1.0000 - LR: 0.000076
# Epoch 13/50 - Train loss: 0.0002 - Val loss: 0.0001 - Val accuracy: 1.0000 - LR: 0.000074
# Epoch 14/50 - Train loss: 0.0003 - Val loss: 0.0002 - Val accuracy: 1.0000 - LR: 0.000072
# Epoch 15/50 - Train loss: 0.0002 - Val loss: 0.0001 - Val accuracy: 1.0000 - LR: 0.000070
# Epoch 16/50 - Train loss: 0.0002 - Val loss: 0.0001 - Val accuracy: 1.0000 - LR: 0.000068
# Epoch 17/50 - Train loss: 0.0002 - Val loss: 0.0001 - Val accuracy: 1.0000 - LR: 0.000066
# Epoch 18/50 - Train loss: 0.0001 - Val loss: 0.0001 - Val accuracy: 1.0000 - LR: 0.000064
# Epoch 19/50 - Train loss: 0.0002 - Val loss: 0.0001 - Val accuracy: 1.0000 - LR: 0.000062
# Epoch 20/50 - Train loss: 0.0001 - Val loss: 0.0001 - Val accuracy: 1.0000 - LR: 0.000060
# Epoch 21/50 - Train loss: 0.0001 - Val loss: 0.0001 - Val accuracy: 1.0000 - LR: 0.000058
# Epoch 22/50 - Train loss: 0.0001 - Val loss: 0.0000 - Val accuracy: 1.0000 - LR: 0.000056
# Epoch 23/50 - Train loss: 0.0001 - Val loss: 0.0000 - Val accuracy: 1.0000 - LR: 0.000054
# Epoch 24/50 - Train loss: 0.0001 - Val loss: 0.0001 - Val accuracy: 1.0000 - LR: 0.000052
# Epoch 25/50 - Train loss: 0.0001 - Val loss: 0.0000 - Val accuracy: 1.0000 - LR: 0.000050
# Epoch 26/50 - Train loss: 0.0001 - Val loss: 0.0000 - Val accuracy: 1.0000 - LR: 0.000048
# Epoch 27/50 - Train loss: 0.0001 - Val loss: 0.0000 - Val accuracy: 1.0000 - LR: 0.000046
# Epoch 28/50 - Train loss: 0.0001 - Val loss: 0.0000 - Val accuracy: 1.0000 - LR: 0.000044
# Epoch 29/50 - Train loss: 0.0001 - Val loss: 0.0000 - Val accuracy: 1.0000 - LR: 0.000042
# Epoch 30/50 - Train loss: 0.0001 - Val loss: 0.0000 - Val accuracy: 1.0000 - LR: 0.000040
# Epoch 31/50 - Train loss: 0.0001 - Val loss: 0.0000 - Val accuracy: 1.0000 - LR: 0.000038
# Epoch 32/50 - Train loss: 0.0001 - Val loss: 0.0000 - Val accuracy: 1.0000 - LR: 0.000036
# Epoch 33/50 - Train loss: 0.0000 - Val loss: 0.0000 - Val accuracy: 1.0000 - LR: 0.000034
# Epoch 34/50 - Train loss: 0.0001 - Val loss: 0.0000 - Val accuracy: 1.0000 - LR: 0.000032
# Epoch 35/50 - Train loss: 0.0000 - Val loss: 0.0000 - Val accuracy: 1.0000 - LR: 0.000030
# Epoch 36/50 - Train loss: 0.0000 - Val loss: 0.0000 - Val accuracy: 1.0000 - LR: 0.000028
# Epoch 37/50 - Train loss: 0.0000 - Val loss: 0.0000 - Val accuracy: 1.0000 - LR: 0.000026
# Epoch 38/50 - Train loss: 0.0000 - Val loss: 0.0000 - Val accuracy: 1.0000 - LR: 0.000024
# Epoch 39/50 - Train loss: 0.0000 - Val loss: 0.0000 - Val accuracy: 1.0000 - LR: 0.000022
# Epoch 40/50 - Train loss: 0.0000 - Val loss: 0.0000 - Val accuracy: 1.0000 - LR: 0.000020
# Epoch 41/50 - Train loss: 0.0000 - Val loss: 0.0000 - Val accuracy: 1.0000 - LR: 0.000018
# Epoch 42/50 - Train loss: 0.0000 - Val loss: 0.0000 - Val accuracy: 1.0000 - LR: 0.000016
# Epoch 43/50 - Train loss: 0.0000 - Val loss: 0.0000 - Val accuracy: 1.0000 - LR: 0.000014
# Epoch 44/50 - Train loss: 0.0000 - Val loss: 0.0000 - Val accuracy: 1.0000 - LR: 0.000012
# Epoch 45/50 - Train loss: 0.0001 - Val loss: 0.0000 - Val accuracy: 1.0000 - LR: 0.000010
# Epoch 46/50 - Train loss: 0.0000 - Val loss: 0.0000 - Val accuracy: 1.0000 - LR: 0.000008
# Epoch 47/50 - Train loss: 0.0000 - Val loss: 0.0000 - Val accuracy: 1.0000 - LR: 0.000006
# Epoch 48/50 - Train loss: 0.0000 - Val loss: 0.0000 - Val accuracy: 1.0000 - LR: 0.000004
# Epoch 49/50 - Train loss: 0.0000 - Val loss: 0.0000 - Val accuracy: 1.0000 - LR: 0.000002
# Epoch 50/50 - Train loss: 0.0000 - Val loss: 0.0000 - Val accuracy: 1.0000 - LR: 0.000000
# Best epoch: 1 - Best val accuracy: 1.0000 - Best val loss: 0.0447
# Source: Ball - Domain: 4 - Accuracy: 0.36 - Loss: 4.6911
# Source: Ball - Domain: 5 - Accuracy: 0.31 - Loss: 5.1584
# Source: Ball - Domain: 6 - Accuracy: 0.31 - Loss: 5.3033
# Source: Ball - Domain: 7 - Accuracy: 0.31 - Loss: 5.0723
# Ball -> ['IR', 'OR_centred', 'OR_orthogonal', 'OR_opposite']: 0.32
#
#
# Epoch 1/50 - Train loss: 0.4525 - Val loss: 0.2302 - Val accuracy: 0.8939 - LR: 0.000098
# Epoch 2/50 - Train loss: 0.0724 - Val loss: 0.1062 - Val accuracy: 0.9609 - LR: 0.000096
# Epoch 3/50 - Train loss: 0.0269 - Val loss: 0.0418 - Val accuracy: 0.9881 - LR: 0.000094
# Epoch 4/50 - Train loss: 0.0128 - Val loss: 0.0184 - Val accuracy: 0.9960 - LR: 0.000092
# Epoch 5/50 - Train loss: 0.0090 - Val loss: 0.0217 - Val accuracy: 0.9914 - LR: 0.000090
# Epoch 6/50 - Train loss: 0.0075 - Val loss: 0.0059 - Val accuracy: 0.9993 - LR: 0.000088
# Epoch 7/50 - Train loss: 0.0052 - Val loss: 0.0316 - Val accuracy: 0.9874 - LR: 0.000086
# Epoch 8/50 - Train loss: 0.0031 - Val loss: 0.0104 - Val accuracy: 0.9960 - LR: 0.000084
# Epoch 9/50 - Train loss: 0.0067 - Val loss: 0.0048 - Val accuracy: 0.9993 - LR: 0.000082
# Epoch 10/50 - Train loss: 0.0141 - Val loss: 0.0036 - Val accuracy: 0.9993 - LR: 0.000080
# Epoch 11/50 - Train loss: 0.0022 - Val loss: 0.0031 - Val accuracy: 0.9993 - LR: 0.000078
# Epoch 12/50 - Train loss: 0.0045 - Val loss: 0.0025 - Val accuracy: 0.9993 - LR: 0.000076
# Epoch 13/50 - Train loss: 0.0017 - Val loss: 0.0023 - Val accuracy: 0.9993 - LR: 0.000074
# Epoch 14/50 - Train loss: 0.0021 - Val loss: 0.0012 - Val accuracy: 0.9993 - LR: 0.000072
# Epoch 15/50 - Train loss: 0.0052 - Val loss: 0.0015 - Val accuracy: 0.9993 - LR: 0.000070
# Epoch 16/50 - Train loss: 0.0040 - Val loss: 0.0011 - Val accuracy: 0.9993 - LR: 0.000068
# Epoch 17/50 - Train loss: 0.0011 - Val loss: 0.0009 - Val accuracy: 1.0000 - LR: 0.000066
# Epoch 18/50 - Train loss: 0.0017 - Val loss: 0.0059 - Val accuracy: 0.9980 - LR: 0.000064
# Epoch 19/50 - Train loss: 0.0016 - Val loss: 0.0008 - Val accuracy: 0.9993 - LR: 0.000062
# Epoch 20/50 - Train loss: 0.0037 - Val loss: 0.0093 - Val accuracy: 0.9967 - LR: 0.000060
# Epoch 21/50 - Train loss: 0.0022 - Val loss: 0.0019 - Val accuracy: 0.9993 - LR: 0.000058
# Epoch 22/50 - Train loss: 0.0007 - Val loss: 0.0054 - Val accuracy: 0.9993 - LR: 0.000056
# Epoch 23/50 - Train loss: 0.0017 - Val loss: 0.0004 - Val accuracy: 1.0000 - LR: 0.000054
# Epoch 24/50 - Train loss: 0.0005 - Val loss: 0.0006 - Val accuracy: 0.9993 - LR: 0.000052
# Epoch 25/50 - Train loss: 0.0006 - Val loss: 0.0017 - Val accuracy: 0.9993 - LR: 0.000050
# Epoch 26/50 - Train loss: 0.0008 - Val loss: 0.0011 - Val accuracy: 0.9993 - LR: 0.000048
# Epoch 27/50 - Train loss: 0.0003 - Val loss: 0.0015 - Val accuracy: 0.9993 - LR: 0.000046
# Epoch 28/50 - Train loss: 0.0007 - Val loss: 0.0004 - Val accuracy: 1.0000 - LR: 0.000044
# Epoch 29/50 - Train loss: 0.0004 - Val loss: 0.0005 - Val accuracy: 1.0000 - LR: 0.000042
# Epoch 30/50 - Train loss: 0.0003 - Val loss: 0.0012 - Val accuracy: 0.9993 - LR: 0.000040
# Epoch 31/50 - Train loss: 0.0015 - Val loss: 0.0004 - Val accuracy: 1.0000 - LR: 0.000038
# Epoch 32/50 - Train loss: 0.0004 - Val loss: 0.0007 - Val accuracy: 0.9993 - LR: 0.000036
# Epoch 33/50 - Train loss: 0.0002 - Val loss: 0.0005 - Val accuracy: 1.0000 - LR: 0.000034
# Epoch 34/50 - Train loss: 0.0002 - Val loss: 0.0010 - Val accuracy: 0.9993 - LR: 0.000032
# Epoch 35/50 - Train loss: 0.0006 - Val loss: 0.0016 - Val accuracy: 0.9993 - LR: 0.000030
# Epoch 36/50 - Train loss: 0.0033 - Val loss: 0.0004 - Val accuracy: 1.0000 - LR: 0.000028
# Epoch 37/50 - Train loss: 0.0027 - Val loss: 0.0004 - Val accuracy: 1.0000 - LR: 0.000026
# Epoch 38/50 - Train loss: 0.0003 - Val loss: 0.0005 - Val accuracy: 0.9993 - LR: 0.000024
# Epoch 39/50 - Train loss: 0.0002 - Val loss: 0.0005 - Val accuracy: 0.9993 - LR: 0.000022
# Epoch 40/50 - Train loss: 0.0006 - Val loss: 0.0020 - Val accuracy: 0.9993 - LR: 0.000020
# Epoch 41/50 - Train loss: 0.0004 - Val loss: 0.0002 - Val accuracy: 1.0000 - LR: 0.000018
# Epoch 42/50 - Train loss: 0.0004 - Val loss: 0.0002 - Val accuracy: 1.0000 - LR: 0.000016
# Epoch 43/50 - Train loss: 0.0002 - Val loss: 0.0002 - Val accuracy: 1.0000 - LR: 0.000014
# Epoch 44/50 - Train loss: 0.0002 - Val loss: 0.0003 - Val accuracy: 1.0000 - LR: 0.000012
# Epoch 45/50 - Train loss: 0.0003 - Val loss: 0.0004 - Val accuracy: 1.0000 - LR: 0.000010
# Epoch 46/50 - Train loss: 0.0002 - Val loss: 0.0006 - Val accuracy: 0.9993 - LR: 0.000008
# Epoch 47/50 - Train loss: 0.0002 - Val loss: 0.0003 - Val accuracy: 1.0000 - LR: 0.000006
# Epoch 48/50 - Train loss: 0.0004 - Val loss: 0.0004 - Val accuracy: 1.0000 - LR: 0.000004
# Epoch 49/50 - Train loss: 0.0030 - Val loss: 0.0004 - Val accuracy: 1.0000 - LR: 0.000002
# Epoch 50/50 - Train loss: 0.0002 - Val loss: 0.0004 - Val accuracy: 1.0000 - LR: 0.000000
# Best epoch: 17 - Best val accuracy: 1.0000 - Best val loss: 0.0009
# Source: OR_centred - Domain: 4 - Accuracy: 0.50 - Loss: 5.4056
# Source: OR_centred - Domain: 5 - Accuracy: 0.42 - Loss: 4.8604
# Source: OR_centred - Domain: 6 - Accuracy: 0.41 - Loss: 4.9026
# Source: OR_centred - Domain: 7 - Accuracy: 0.26 - Loss: 5.8972
# OR_centred -> ['IR', 'Ball', 'OR_orthogonal', 'OR_opposite']: 0.40
#
#
# Epoch 1/50 - Train loss: 0.5075 - Val loss: 0.1537 - Val accuracy: 0.9768 - LR: 0.000098
# Epoch 2/50 - Train loss: 0.0930 - Val loss: 0.3417 - Val accuracy: 0.8700 - LR: 0.000096
# Epoch 3/50 - Train loss: 0.0283 - Val loss: 0.0545 - Val accuracy: 0.9781 - LR: 0.000094
# Epoch 4/50 - Train loss: 0.0129 - Val loss: 0.0085 - Val accuracy: 0.9987 - LR: 0.000092
# Epoch 5/50 - Train loss: 0.0090 - Val loss: 0.0032 - Val accuracy: 1.0000 - LR: 0.000090
# Epoch 6/50 - Train loss: 0.0057 - Val loss: 0.0053 - Val accuracy: 0.9987 - LR: 0.000088
# Epoch 7/50 - Train loss: 0.0049 - Val loss: 0.0101 - Val accuracy: 0.9973 - LR: 0.000086
# Epoch 8/50 - Train loss: 0.0032 - Val loss: 0.0127 - Val accuracy: 0.9934 - LR: 0.000084
# Epoch 9/50 - Train loss: 0.0029 - Val loss: 0.0009 - Val accuracy: 1.0000 - LR: 0.000082
# Epoch 10/50 - Train loss: 0.0022 - Val loss: 0.0007 - Val accuracy: 1.0000 - LR: 0.000080
# Epoch 11/50 - Train loss: 0.0078 - Val loss: 0.0014 - Val accuracy: 1.0000 - LR: 0.000078
# Epoch 12/50 - Train loss: 0.0049 - Val loss: 0.0056 - Val accuracy: 1.0000 - LR: 0.000076
# Epoch 13/50 - Train loss: 0.0015 - Val loss: 0.0011 - Val accuracy: 1.0000 - LR: 0.000074
# Epoch 14/50 - Train loss: 0.0009 - Val loss: 0.0004 - Val accuracy: 1.0000 - LR: 0.000072
# Epoch 15/50 - Train loss: 0.0007 - Val loss: 0.0007 - Val accuracy: 1.0000 - LR: 0.000070
# Epoch 16/50 - Train loss: 0.0008 - Val loss: 0.0003 - Val accuracy: 1.0000 - LR: 0.000068
# Epoch 17/50 - Train loss: 0.0007 - Val loss: 0.0006 - Val accuracy: 1.0000 - LR: 0.000066
# Epoch 18/50 - Train loss: 0.0011 - Val loss: 0.0184 - Val accuracy: 0.9920 - LR: 0.000064
# Epoch 19/50 - Train loss: 0.0004 - Val loss: 0.0003 - Val accuracy: 1.0000 - LR: 0.000062
# Epoch 20/50 - Train loss: 0.0009 - Val loss: 0.0003 - Val accuracy: 1.0000 - LR: 0.000060
# Epoch 21/50 - Train loss: 0.0024 - Val loss: 0.0002 - Val accuracy: 1.0000 - LR: 0.000058
# Epoch 22/50 - Train loss: 0.0005 - Val loss: 0.0003 - Val accuracy: 1.0000 - LR: 0.000056
# Epoch 23/50 - Train loss: 0.0003 - Val loss: 0.0002 - Val accuracy: 1.0000 - LR: 0.000054
# Epoch 24/50 - Train loss: 0.0003 - Val loss: 0.0002 - Val accuracy: 1.0000 - LR: 0.000052
# Epoch 25/50 - Train loss: 0.0004 - Val loss: 0.0003 - Val accuracy: 1.0000 - LR: 0.000050
# Epoch 26/50 - Train loss: 0.0003 - Val loss: 0.0002 - Val accuracy: 1.0000 - LR: 0.000048
# Epoch 27/50 - Train loss: 0.0003 - Val loss: 0.0001 - Val accuracy: 1.0000 - LR: 0.000046
# Epoch 28/50 - Train loss: 0.0006 - Val loss: 0.0001 - Val accuracy: 1.0000 - LR: 0.000044
# Epoch 29/50 - Train loss: 0.0004 - Val loss: 0.0002 - Val accuracy: 1.0000 - LR: 0.000042
# Epoch 30/50 - Train loss: 0.0003 - Val loss: 0.0001 - Val accuracy: 1.0000 - LR: 0.000040
# Epoch 31/50 - Train loss: 0.0002 - Val loss: 0.0001 - Val accuracy: 1.0000 - LR: 0.000038
# Epoch 32/50 - Train loss: 0.0009 - Val loss: 0.0001 - Val accuracy: 1.0000 - LR: 0.000036
# Epoch 33/50 - Train loss: 0.0002 - Val loss: 0.0002 - Val accuracy: 1.0000 - LR: 0.000034
# Epoch 34/50 - Train loss: 0.0002 - Val loss: 0.0001 - Val accuracy: 1.0000 - LR: 0.000032
# Epoch 35/50 - Train loss: 0.0002 - Val loss: 0.0001 - Val accuracy: 1.0000 - LR: 0.000030
# Epoch 36/50 - Train loss: 0.0001 - Val loss: 0.0001 - Val accuracy: 1.0000 - LR: 0.000028
# Epoch 37/50 - Train loss: 0.0001 - Val loss: 0.0001 - Val accuracy: 1.0000 - LR: 0.000026
# Epoch 38/50 - Train loss: 0.0001 - Val loss: 0.0001 - Val accuracy: 1.0000 - LR: 0.000024
# Epoch 39/50 - Train loss: 0.0001 - Val loss: 0.0001 - Val accuracy: 1.0000 - LR: 0.000022
# Epoch 40/50 - Train loss: 0.0002 - Val loss: 0.0001 - Val accuracy: 1.0000 - LR: 0.000020
# Epoch 41/50 - Train loss: 0.0001 - Val loss: 0.0001 - Val accuracy: 1.0000 - LR: 0.000018
# Epoch 42/50 - Train loss: 0.0003 - Val loss: 0.0001 - Val accuracy: 1.0000 - LR: 0.000016
# Epoch 43/50 - Train loss: 0.0001 - Val loss: 0.0001 - Val accuracy: 1.0000 - LR: 0.000014
# Epoch 44/50 - Train loss: 0.0002 - Val loss: 0.0001 - Val accuracy: 1.0000 - LR: 0.000012
# Epoch 45/50 - Train loss: 0.0002 - Val loss: 0.0001 - Val accuracy: 1.0000 - LR: 0.000010
# Epoch 46/50 - Train loss: 0.0002 - Val loss: 0.0001 - Val accuracy: 1.0000 - LR: 0.000008
# Epoch 47/50 - Train loss: 0.0001 - Val loss: 0.0001 - Val accuracy: 1.0000 - LR: 0.000006
# Epoch 48/50 - Train loss: 0.0001 - Val loss: 0.0001 - Val accuracy: 1.0000 - LR: 0.000004
# Epoch 49/50 - Train loss: 0.0004 - Val loss: 0.0001 - Val accuracy: 1.0000 - LR: 0.000002
# Epoch 50/50 - Train loss: 0.0002 - Val loss: 0.0001 - Val accuracy: 1.0000 - LR: 0.000000
# Best epoch: 5 - Best val accuracy: 1.0000 - Best val loss: 0.0032
# Source: OR_orthogonal - Domain: 4 - Accuracy: 0.43 - Loss: 4.8995
# Source: OR_orthogonal - Domain: 5 - Accuracy: 0.44 - Loss: 3.5334
# Source: OR_orthogonal - Domain: 6 - Accuracy: 0.43 - Loss: 3.6807
# Source: OR_orthogonal - Domain: 7 - Accuracy: 0.44 - Loss: 3.6015
# OR_orthogonal -> ['IR', 'Ball', 'OR_centred', 'OR_opposite']: 0.44
#
#
# Epoch 1/50 - Train loss: 0.3413 - Val loss: 0.0206 - Val accuracy: 1.0000 - LR: 0.000098
# Epoch 2/50 - Train loss: 0.0074 - Val loss: 0.0024 - Val accuracy: 1.0000 - LR: 0.000096
# Epoch 3/50 - Train loss: 0.0031 - Val loss: 0.0011 - Val accuracy: 1.0000 - LR: 0.000094
# Epoch 4/50 - Train loss: 0.0018 - Val loss: 0.0006 - Val accuracy: 1.0000 - LR: 0.000092
# Epoch 5/50 - Train loss: 0.0010 - Val loss: 0.0004 - Val accuracy: 1.0000 - LR: 0.000090
# Epoch 6/50 - Train loss: 0.0007 - Val loss: 0.0003 - Val accuracy: 1.0000 - LR: 0.000088
# Epoch 7/50 - Train loss: 0.0005 - Val loss: 0.0002 - Val accuracy: 1.0000 - LR: 0.000086
# Epoch 8/50 - Train loss: 0.0004 - Val loss: 0.0002 - Val accuracy: 1.0000 - LR: 0.000084
# Epoch 9/50 - Train loss: 0.0004 - Val loss: 0.0001 - Val accuracy: 1.0000 - LR: 0.000082
# Epoch 10/50 - Train loss: 0.0003 - Val loss: 0.0001 - Val accuracy: 1.0000 - LR: 0.000080
# Epoch 11/50 - Train loss: 0.0003 - Val loss: 0.0001 - Val accuracy: 1.0000 - LR: 0.000078
# Epoch 12/50 - Train loss: 0.0003 - Val loss: 0.0001 - Val accuracy: 1.0000 - LR: 0.000076
# Epoch 13/50 - Train loss: 0.0008 - Val loss: 0.0001 - Val accuracy: 1.0000 - LR: 0.000074
# Epoch 14/50 - Train loss: 0.0005 - Val loss: 0.0001 - Val accuracy: 1.0000 - LR: 0.000072
# Epoch 15/50 - Train loss: 0.0001 - Val loss: 0.0001 - Val accuracy: 1.0000 - LR: 0.000070
# Epoch 16/50 - Train loss: 0.0001 - Val loss: 0.0000 - Val accuracy: 1.0000 - LR: 0.000068
# Epoch 17/50 - Train loss: 0.0001 - Val loss: 0.0000 - Val accuracy: 1.0000 - LR: 0.000066
# Epoch 18/50 - Train loss: 0.0001 - Val loss: 0.0000 - Val accuracy: 1.0000 - LR: 0.000064
# Epoch 19/50 - Train loss: 0.0001 - Val loss: 0.0000 - Val accuracy: 1.0000 - LR: 0.000062
# Epoch 20/50 - Train loss: 0.0001 - Val loss: 0.0000 - Val accuracy: 1.0000 - LR: 0.000060
# Epoch 21/50 - Train loss: 0.0001 - Val loss: 0.0000 - Val accuracy: 1.0000 - LR: 0.000058
# Epoch 22/50 - Train loss: 0.0001 - Val loss: 0.0000 - Val accuracy: 1.0000 - LR: 0.000056
# Epoch 23/50 - Train loss: 0.0001 - Val loss: 0.0000 - Val accuracy: 1.0000 - LR: 0.000054
# Epoch 24/50 - Train loss: 0.0001 - Val loss: 0.0000 - Val accuracy: 1.0000 - LR: 0.000052
# Epoch 25/50 - Train loss: 0.0000 - Val loss: 0.0000 - Val accuracy: 1.0000 - LR: 0.000050
# Epoch 26/50 - Train loss: 0.0000 - Val loss: 0.0000 - Val accuracy: 1.0000 - LR: 0.000048
# Epoch 27/50 - Train loss: 0.0004 - Val loss: 0.0000 - Val accuracy: 1.0000 - LR: 0.000046
# Epoch 28/50 - Train loss: 0.0001 - Val loss: 0.0000 - Val accuracy: 1.0000 - LR: 0.000044
# Epoch 29/50 - Train loss: 0.0001 - Val loss: 0.0000 - Val accuracy: 1.0000 - LR: 0.000042
# Epoch 30/50 - Train loss: 0.0001 - Val loss: 0.0000 - Val accuracy: 1.0000 - LR: 0.000040
# Epoch 31/50 - Train loss: 0.0000 - Val loss: 0.0000 - Val accuracy: 1.0000 - LR: 0.000038
# Epoch 32/50 - Train loss: 0.0002 - Val loss: 0.0000 - Val accuracy: 1.0000 - LR: 0.000036
# Epoch 33/50 - Train loss: 0.0001 - Val loss: 0.0000 - Val accuracy: 1.0000 - LR: 0.000034
# Epoch 34/50 - Train loss: 0.0001 - Val loss: 0.0000 - Val accuracy: 1.0000 - LR: 0.000032
# Epoch 35/50 - Train loss: 0.0000 - Val loss: 0.0000 - Val accuracy: 1.0000 - LR: 0.000030
# Epoch 36/50 - Train loss: 0.0000 - Val loss: 0.0000 - Val accuracy: 1.0000 - LR: 0.000028
# Epoch 37/50 - Train loss: 0.0000 - Val loss: 0.0000 - Val accuracy: 1.0000 - LR: 0.000026
# Epoch 38/50 - Train loss: 0.0000 - Val loss: 0.0000 - Val accuracy: 1.0000 - LR: 0.000024
# Epoch 39/50 - Train loss: 0.0000 - Val loss: 0.0000 - Val accuracy: 1.0000 - LR: 0.000022
# Epoch 40/50 - Train loss: 0.0000 - Val loss: 0.0000 - Val accuracy: 1.0000 - LR: 0.000020
# Epoch 41/50 - Train loss: 0.0000 - Val loss: 0.0000 - Val accuracy: 1.0000 - LR: 0.000018
# Epoch 42/50 - Train loss: 0.0000 - Val loss: 0.0000 - Val accuracy: 1.0000 - LR: 0.000016
# Epoch 43/50 - Train loss: 0.0000 - Val loss: 0.0000 - Val accuracy: 1.0000 - LR: 0.000014
# Epoch 44/50 - Train loss: 0.0000 - Val loss: 0.0000 - Val accuracy: 1.0000 - LR: 0.000012
# Epoch 45/50 - Train loss: 0.0000 - Val loss: 0.0000 - Val accuracy: 1.0000 - LR: 0.000010
# Epoch 46/50 - Train loss: 0.0000 - Val loss: 0.0000 - Val accuracy: 1.0000 - LR: 0.000008
# Epoch 47/50 - Train loss: 0.0000 - Val loss: 0.0000 - Val accuracy: 1.0000 - LR: 0.000006
# Epoch 48/50 - Train loss: 0.0000 - Val loss: 0.0000 - Val accuracy: 1.0000 - LR: 0.000004
# Epoch 49/50 - Train loss: 0.0000 - Val loss: 0.0000 - Val accuracy: 1.0000 - LR: 0.000002
# Epoch 50/50 - Train loss: 0.0000 - Val loss: 0.0000 - Val accuracy: 1.0000 - LR: 0.000000
# Best epoch: 1 - Best val accuracy: 1.0000 - Best val loss: 0.0206
# Source: OR_opposite - Domain: 4 - Accuracy: 0.46 - Loss: 4.1125
# Source: OR_opposite - Domain: 5 - Accuracy: 0.40 - Loss: 4.6332
# Source: OR_opposite - Domain: 6 - Accuracy: 0.40 - Loss: 4.9570
# Source: OR_opposite - Domain: 7 - Accuracy: 0.40 - Loss: 4.8199
# OR_opposite -> ['IR', 'Ball', 'OR_centred', 'OR_orthogonal']: 0.41
#
#
# Mean accuracy: 0.41
