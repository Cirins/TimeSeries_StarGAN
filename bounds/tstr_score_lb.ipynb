# %%
from google.colab import drive
drive.mount('/content/drive')

# %cd drive/MyDrive/ST/stargan
# Out:
# Mounted at /content/drive
# /content/drive/MyDrive/ST/stargan

# %%
import pickle
import numpy as np
from sklearn.model_selection import train_test_split
import torch
import torch.nn as nn
from torch.utils.data import DataLoader, TensorDataset
from torch.optim.lr_scheduler import LambdaLR
import torch.optim as optim

# %%
class TSTRClassifier(nn.Module):
    def __init__(self, num_timesteps=128, num_channels=3, num_classes=5):
        super(TSTRClassifier, self).__init__()

        self.conv1 = nn.Conv1d(num_channels, 16, kernel_size=5, stride=1, padding=2)
        self.bn1 = nn.BatchNorm1d(16)
        self.conv2 = nn.Conv1d(16, 32, kernel_size=5, stride=1, padding=2)
        self.bn2 = nn.BatchNorm1d(32)
        self.conv3 = nn.Conv1d(32, 64, kernel_size=5, stride=1, padding=2)
        self.bn3 = nn.BatchNorm1d(64)
        self.conv4 = nn.Conv1d(64, 128, kernel_size=5, stride=1, padding=2)
        self.bn4 = nn.BatchNorm1d(128)
        self.pool = nn.MaxPool1d(kernel_size=2, stride=2)
        self.relu = nn.ReLU()
        self.dropout = nn.Dropout(p=0.25)

        self.fc_shared = nn.Linear(num_timesteps * 8, 100)

        self.fc_class = nn.Linear(100, num_classes)

    def forward(self, x):
        x = self.pool(self.relu(self.bn1(self.conv1(x))))
        x = self.pool(self.relu(self.bn2(self.conv2(x))))
        x = self.pool(self.relu(self.bn3(self.conv3(x))))
        x = self.pool(self.relu(self.bn4(self.conv4(x))))
        x = x.view(x.size(0), -1)  # Flatten
        x = self.dropout(x)
        x = self.relu(self.fc_shared(x))

        # Final output for class prediction
        class_outputs = self.fc_class(x)
        return class_outputs


def get_df_data(dataset_name, class_idx, num_train_domains):

    # Load the dataset
    with open(f'data/{dataset_name}.pkl', 'rb') as f:
        x, y, k = pickle.load(f)

    with open(f'data/{dataset_name}_fs.pkl', 'rb') as f:
        fs = pickle.load(f)

    # Filter out the samples that are used for finetuning
    x = x[fs == 0]
    y = y[fs == 0]
    k = k[fs == 0]

    x_ = x[(y == class_idx) & (k < num_train_domains)]
    y_ = y[(y == class_idx) & (k < num_train_domains)]
    k_ = k[(y == class_idx) & (k < num_train_domains)]

    return x_, y_, k_


def get_dp_data(dataset_name, class_idx, num_train_domains):

    # Load the dataset
    with open(f'data/{dataset_name}.pkl', 'rb') as f:
        x, y, k = pickle.load(f)

    with open(f'data/{dataset_name}_fs.pkl', 'rb') as f:
        fs = pickle.load(f)

    # Filter out the samples that are used for finetuning
    x = x[fs == 0]
    y = y[fs == 0]
    k = k[fs == 0]

    x_ = x[(y == class_idx) & (k >= num_train_domains)]
    y_ = y[(y == class_idx) & (k >= num_train_domains)]
    k_ = k[(y == class_idx) & (k >= num_train_domains)] - num_train_domains

    return x_, y_, k_


def remap_labels(y):
    label_map = {clss: i for i, clss in enumerate(np.unique(y))}
    return np.array([label_map[clss] for clss in y])


def setup_training(x_tr, y_tr, x_val, y_val, x_test, y_test, batch_size=64):
    # Convert numpy arrays to torch tensors
    x_train_tensor = torch.tensor(x_tr, dtype=torch.float32)
    y_train_tensor = torch.tensor(y_tr, dtype=torch.long)
    x_val_tensor = torch.tensor(x_val, dtype=torch.float32)
    y_val_tensor = torch.tensor(y_val, dtype=torch.long)
    x_test_tensor = torch.tensor(x_test, dtype=torch.float32)
    y_test_tensor = torch.tensor(y_test, dtype=torch.long)

    # Create datasets and loaders
    train_dataset = TensorDataset(x_train_tensor, y_train_tensor)
    train_loader = DataLoader(train_dataset, batch_size=batch_size, shuffle=True)
    val_dataset = TensorDataset(x_val_tensor, y_val_tensor)
    val_loader = DataLoader(val_dataset, batch_size=batch_size, shuffle=False)
    test_dataset = TensorDataset(x_test_tensor, y_test_tensor)
    test_loader = DataLoader(test_dataset, batch_size=batch_size, shuffle=False)

    return train_loader, val_loader, test_loader


def train_model(model, train_loader, val_loader, loss_fn, optimizer, epochs=300):
    device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
    model.to(device)

    loss_train = []
    loss_val = []
    accuracy_val = []
    best_loss = np.inf
    best_accuracy = 0

    # Set up linear learning rate decay
    lambda_lr = lambda epoch: 1 - epoch / epochs
    scheduler = LambdaLR(optimizer, lr_lambda=lambda_lr)

    for epoch in range(epochs):
        model.train()
        total_loss = 0
        for x_batch, y_batch in train_loader:
            x_batch, y_batch = x_batch.to(device), y_batch.to(device)
            optimizer.zero_grad()
            outputs = model(x_batch)
            loss = loss_fn(outputs, y_batch)
            loss.backward()
            optimizer.step()
            total_loss += loss.item()
        total_loss /= len(train_loader)
        loss_train.append(total_loss)

        # Update learning rate
        scheduler.step()

        val_accuracy, val_loss = evaluate_model(model, val_loader, loss_fn)
        if val_accuracy > best_accuracy:
            best_epoch = epoch
            best_accuracy = val_accuracy
            best_loss = val_loss
            best_model_state = model.state_dict().copy()
        loss_val.append(val_loss)
        accuracy_val.append(val_accuracy)

        current_lr = scheduler.get_last_lr()[0]
        print(f"Epoch {epoch + 1}/{epochs} - Train loss: {total_loss:.4f} - Val loss: {val_loss:.4f} - Val accuracy: {val_accuracy:.4f} - LR: {current_lr:.6f}")

    print(f"\nBest epoch: {best_epoch + 1} - Best val accuracy: {best_accuracy:.4f} - Best val loss: {best_loss:.4f}\n")

    return best_model_state


def evaluate_model(model, test_loader, loss_fn):
    device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
    model.to(device)
    model.eval()
    total_loss = 0
    correct_predictions = 0
    total_predictions = 0

    with torch.no_grad():
        for x_batch, y_batch in test_loader:
            x_batch, y_batch = x_batch.to(device), y_batch.to(device)
            outputs = model(x_batch)
            loss = loss_fn(outputs, y_batch)
            total_loss += loss.item()

            _, predicted_labels = torch.max(outputs, 1)
            correct_predictions += (predicted_labels == y_batch).sum().item()
            total_predictions += len(y_batch)

    total_loss /= len(test_loader)
    accuracy = correct_predictions / total_predictions

    return accuracy, total_loss


def calculate_tstr_score(x_train, y_train, x_test, y_test):
    # Remap labels
    y_train = remap_labels(y_train)
    y_test = remap_labels(y_test)

    x_tr, x_val, y_tr, y_val = train_test_split(x_train, y_train, test_size=0.2, random_state=2710, stratify=y_train, shuffle=True)
    tr_loader, val_loader, test_loader = setup_training(x_tr, y_tr, x_val, y_val, x_test, y_test, batch_size=64)

    model = TSTRClassifier(num_timesteps=x_train.shape[2], num_channels=x_train.shape[1], num_classes=len(np.unique(y_train)))
    loss_fn = nn.CrossEntropyLoss()
    initial_lr = 0.0001
    optimizer = optim.Adam(model.parameters(), lr=initial_lr)

    best_model_state = train_model(model, tr_loader, val_loader, loss_fn, optimizer, epochs=50)
    best_model = TSTRClassifier(num_timesteps=x_train.shape[2], num_channels=x_train.shape[1], num_classes=len(np.unique(y_train)))
    best_model.load_state_dict(best_model_state)
    test_accuracy, test_loss = evaluate_model(best_model, test_loader, loss_fn)

    return test_accuracy, test_loss

# %%
dataset = 'realworld'

if dataset == 'realworld':
    dataset_name = 'realworld_128_3ch_4cl'
    num_df_domains = 10
    num_dp_domains = 5
    num_classes = 4
    class_names = ['WAL', 'RUN', 'CLD', 'CLU']

elif dataset == 'cwru':
    dataset_name = 'cwru_256_3ch_5cl'
    num_df_domains = 4
    num_dp_domains = 4
    num_classes = 5
    class_names = ['IR', 'Ball', 'OR_centred', 'OR_orthogonal', 'OR_opposite']

classes_dict = {clss: i for i, clss in enumerate(class_names)}

accs = []

for src_class in class_names:
    trg_classes = [clss for clss in class_names if clss != src_class]

    x_df = []
    y_df = []
    k_df = []

    x_dp = []
    y_dp = []
    k_dp = []

    for trg_class in trg_classes:
        x_df_, y_df_, k_df_ = get_df_data(dataset_name, classes_dict[trg_class], num_df_domains)
        x_dp_, y_dp_, k_dp_ = get_dp_data(dataset_name, classes_dict[trg_class], num_df_domains)

        x_df.append(x_df_)
        y_df.append(y_df_)
        k_df.append(k_df_)

        x_dp.append(x_dp_)
        y_dp.append(y_dp_)
        k_dp.append(k_dp_)

    x_df = np.concatenate(x_df, axis=0)
    y_df = np.concatenate(y_df, axis=0)
    k_df = np.concatenate(k_df, axis=0)

    x_dp = np.concatenate(x_dp, axis=0)
    y_dp = np.concatenate(y_dp, axis=0)
    k_dp = np.concatenate(k_dp, axis=0)

    acc, loss = calculate_tstr_score(x_df, y_df, x_dp, y_dp)
    accs.append(acc)

    print(f'{src_class} -> {trg_classes}: {acc:.2f}\n\n')

print(f'Mean accuracy: {np.mean(accs):.2f}')
# Out:
# Epoch 1/50 - Train loss: 0.5332 - Val loss: 0.2753 - Val accuracy: 0.9178 - LR: 0.000098
# Epoch 2/50 - Train loss: 0.2086 - Val loss: 0.1505 - Val accuracy: 0.9527 - LR: 0.000096
# Epoch 3/50 - Train loss: 0.1597 - Val loss: 0.1134 - Val accuracy: 0.9575 - LR: 0.000094
# Epoch 4/50 - Train loss: 0.1048 - Val loss: 0.0993 - Val accuracy: 0.9679 - LR: 0.000092
# Epoch 5/50 - Train loss: 0.0897 - Val loss: 0.0916 - Val accuracy: 0.9631 - LR: 0.000090
# Epoch 6/50 - Train loss: 0.0786 - Val loss: 0.0828 - Val accuracy: 0.9688 - LR: 0.000088
# Epoch 7/50 - Train loss: 0.0681 - Val loss: 0.0822 - Val accuracy: 0.9669 - LR: 0.000086
# Epoch 8/50 - Train loss: 0.0611 - Val loss: 0.0758 - Val accuracy: 0.9716 - LR: 0.000084
# Epoch 9/50 - Train loss: 0.0526 - Val loss: 0.0706 - Val accuracy: 0.9745 - LR: 0.000082
# Epoch 10/50 - Train loss: 0.0568 - Val loss: 0.0664 - Val accuracy: 0.9735 - LR: 0.000080
# Epoch 11/50 - Train loss: 0.0455 - Val loss: 0.0661 - Val accuracy: 0.9726 - LR: 0.000078
# Epoch 12/50 - Train loss: 0.0404 - Val loss: 0.0649 - Val accuracy: 0.9764 - LR: 0.000076
# Epoch 13/50 - Train loss: 0.0323 - Val loss: 0.0593 - Val accuracy: 0.9764 - LR: 0.000074
# Epoch 14/50 - Train loss: 0.0354 - Val loss: 0.0629 - Val accuracy: 0.9764 - LR: 0.000072
# Epoch 15/50 - Train loss: 0.0311 - Val loss: 0.0578 - Val accuracy: 0.9783 - LR: 0.000070
# Epoch 16/50 - Train loss: 0.0246 - Val loss: 0.0563 - Val accuracy: 0.9773 - LR: 0.000068
# Epoch 17/50 - Train loss: 0.0243 - Val loss: 0.0583 - Val accuracy: 0.9764 - LR: 0.000066
# Epoch 18/50 - Train loss: 0.0294 - Val loss: 0.0543 - Val accuracy: 0.9783 - LR: 0.000064
# Epoch 19/50 - Train loss: 0.0209 - Val loss: 0.0567 - Val accuracy: 0.9792 - LR: 0.000062
# Epoch 20/50 - Train loss: 0.0196 - Val loss: 0.0563 - Val accuracy: 0.9792 - LR: 0.000060
# Epoch 21/50 - Train loss: 0.0165 - Val loss: 0.0576 - Val accuracy: 0.9792 - LR: 0.000058
# Epoch 22/50 - Train loss: 0.0128 - Val loss: 0.0561 - Val accuracy: 0.9792 - LR: 0.000056
# Epoch 23/50 - Train loss: 0.0161 - Val loss: 0.0561 - Val accuracy: 0.9792 - LR: 0.000054
# Epoch 24/50 - Train loss: 0.0145 - Val loss: 0.0581 - Val accuracy: 0.9773 - LR: 0.000052
# Epoch 25/50 - Train loss: 0.0142 - Val loss: 0.0606 - Val accuracy: 0.9783 - LR: 0.000050
# Epoch 26/50 - Train loss: 0.0216 - Val loss: 0.0535 - Val accuracy: 0.9792 - LR: 0.000048
# Epoch 27/50 - Train loss: 0.0126 - Val loss: 0.0566 - Val accuracy: 0.9792 - LR: 0.000046
# Epoch 28/50 - Train loss: 0.0092 - Val loss: 0.0573 - Val accuracy: 0.9773 - LR: 0.000044
# Epoch 29/50 - Train loss: 0.0097 - Val loss: 0.0578 - Val accuracy: 0.9783 - LR: 0.000042
# Epoch 30/50 - Train loss: 0.0072 - Val loss: 0.0586 - Val accuracy: 0.9783 - LR: 0.000040
# Epoch 31/50 - Train loss: 0.0117 - Val loss: 0.0586 - Val accuracy: 0.9773 - LR: 0.000038
# Epoch 32/50 - Train loss: 0.0113 - Val loss: 0.0564 - Val accuracy: 0.9792 - LR: 0.000036
# Epoch 33/50 - Train loss: 0.0086 - Val loss: 0.0565 - Val accuracy: 0.9792 - LR: 0.000034
# Epoch 34/50 - Train loss: 0.0066 - Val loss: 0.0576 - Val accuracy: 0.9783 - LR: 0.000032
# Epoch 35/50 - Train loss: 0.0151 - Val loss: 0.0563 - Val accuracy: 0.9802 - LR: 0.000030
# Epoch 36/50 - Train loss: 0.0091 - Val loss: 0.0567 - Val accuracy: 0.9792 - LR: 0.000028
# Epoch 37/50 - Train loss: 0.0071 - Val loss: 0.0564 - Val accuracy: 0.9783 - LR: 0.000026
# Epoch 38/50 - Train loss: 0.0093 - Val loss: 0.0570 - Val accuracy: 0.9802 - LR: 0.000024
# Epoch 39/50 - Train loss: 0.0080 - Val loss: 0.0603 - Val accuracy: 0.9783 - LR: 0.000022
# Epoch 40/50 - Train loss: 0.0060 - Val loss: 0.0614 - Val accuracy: 0.9764 - LR: 0.000020
# Epoch 41/50 - Train loss: 0.0063 - Val loss: 0.0628 - Val accuracy: 0.9792 - LR: 0.000018
# Epoch 42/50 - Train loss: 0.0063 - Val loss: 0.0595 - Val accuracy: 0.9773 - LR: 0.000016
# Epoch 43/50 - Train loss: 0.0056 - Val loss: 0.0612 - Val accuracy: 0.9764 - LR: 0.000014
# Epoch 44/50 - Train loss: 0.0060 - Val loss: 0.0576 - Val accuracy: 0.9820 - LR: 0.000012
# Epoch 45/50 - Train loss: 0.0048 - Val loss: 0.0586 - Val accuracy: 0.9811 - LR: 0.000010
# Epoch 46/50 - Train loss: 0.0095 - Val loss: 0.0620 - Val accuracy: 0.9792 - LR: 0.000008
# Epoch 47/50 - Train loss: 0.0060 - Val loss: 0.0578 - Val accuracy: 0.9811 - LR: 0.000006
# Epoch 48/50 - Train loss: 0.0062 - Val loss: 0.0564 - Val accuracy: 0.9811 - LR: 0.000004
# Epoch 49/50 - Train loss: 0.0044 - Val loss: 0.0566 - Val accuracy: 0.9820 - LR: 0.000002
# Epoch 50/50 - Train loss: 0.0060 - Val loss: 0.0567 - Val accuracy: 0.9820 - LR: 0.000000
#
# Best epoch: 44 - Best val accuracy: 0.9820 - Best val loss: 0.0576
#
# WAL -> ['RUN', 'CLD', 'CLU']: 0.97
#
#
# Epoch 1/50 - Train loss: 0.8700 - Val loss: 0.6978 - Val accuracy: 0.7121 - LR: 0.000098
# Epoch 2/50 - Train loss: 0.5025 - Val loss: 0.3898 - Val accuracy: 0.8637 - LR: 0.000096
# Epoch 3/50 - Train loss: 0.3302 - Val loss: 0.2973 - Val accuracy: 0.9043 - LR: 0.000094
# Epoch 4/50 - Train loss: 0.2558 - Val loss: 0.2657 - Val accuracy: 0.9025 - LR: 0.000092
# Epoch 5/50 - Train loss: 0.2147 - Val loss: 0.2309 - Val accuracy: 0.9125 - LR: 0.000090
# Epoch 6/50 - Train loss: 0.1841 - Val loss: 0.2149 - Val accuracy: 0.9251 - LR: 0.000088
# Epoch 7/50 - Train loss: 0.1653 - Val loss: 0.1994 - Val accuracy: 0.9287 - LR: 0.000086
# Epoch 8/50 - Train loss: 0.1457 - Val loss: 0.1915 - Val accuracy: 0.9296 - LR: 0.000084
# Epoch 9/50 - Train loss: 0.1321 - Val loss: 0.1844 - Val accuracy: 0.9350 - LR: 0.000082
# Epoch 10/50 - Train loss: 0.1204 - Val loss: 0.1827 - Val accuracy: 0.9305 - LR: 0.000080
# Epoch 11/50 - Train loss: 0.1043 - Val loss: 0.1912 - Val accuracy: 0.9332 - LR: 0.000078
# Epoch 12/50 - Train loss: 0.0911 - Val loss: 0.1744 - Val accuracy: 0.9359 - LR: 0.000076
# Epoch 13/50 - Train loss: 0.0844 - Val loss: 0.1790 - Val accuracy: 0.9395 - LR: 0.000074
# Epoch 14/50 - Train loss: 0.0807 - Val loss: 0.1658 - Val accuracy: 0.9377 - LR: 0.000072
# Epoch 15/50 - Train loss: 0.0728 - Val loss: 0.1603 - Val accuracy: 0.9431 - LR: 0.000070
# Epoch 16/50 - Train loss: 0.0684 - Val loss: 0.1607 - Val accuracy: 0.9449 - LR: 0.000068
# Epoch 17/50 - Train loss: 0.0559 - Val loss: 0.1611 - Val accuracy: 0.9431 - LR: 0.000066
# Epoch 18/50 - Train loss: 0.0632 - Val loss: 0.1558 - Val accuracy: 0.9431 - LR: 0.000064
# Epoch 19/50 - Train loss: 0.0469 - Val loss: 0.1505 - Val accuracy: 0.9477 - LR: 0.000062
# Epoch 20/50 - Train loss: 0.0431 - Val loss: 0.1612 - Val accuracy: 0.9431 - LR: 0.000060
# Epoch 21/50 - Train loss: 0.0438 - Val loss: 0.1586 - Val accuracy: 0.9449 - LR: 0.000058
# Epoch 22/50 - Train loss: 0.0381 - Val loss: 0.1651 - Val accuracy: 0.9440 - LR: 0.000056
# Epoch 23/50 - Train loss: 0.0350 - Val loss: 0.1593 - Val accuracy: 0.9422 - LR: 0.000054
# Epoch 24/50 - Train loss: 0.0369 - Val loss: 0.1597 - Val accuracy: 0.9468 - LR: 0.000052
# Epoch 25/50 - Train loss: 0.0343 - Val loss: 0.1598 - Val accuracy: 0.9449 - LR: 0.000050
# Epoch 26/50 - Train loss: 0.0339 - Val loss: 0.1622 - Val accuracy: 0.9486 - LR: 0.000048
# Epoch 27/50 - Train loss: 0.0280 - Val loss: 0.1575 - Val accuracy: 0.9449 - LR: 0.000046
# Epoch 28/50 - Train loss: 0.0255 - Val loss: 0.1588 - Val accuracy: 0.9468 - LR: 0.000044
# Epoch 29/50 - Train loss: 0.0250 - Val loss: 0.1573 - Val accuracy: 0.9486 - LR: 0.000042
# Epoch 30/50 - Train loss: 0.0223 - Val loss: 0.1564 - Val accuracy: 0.9486 - LR: 0.000040
# Epoch 31/50 - Train loss: 0.0238 - Val loss: 0.1557 - Val accuracy: 0.9486 - LR: 0.000038
# Epoch 32/50 - Train loss: 0.0193 - Val loss: 0.1641 - Val accuracy: 0.9458 - LR: 0.000036
# Epoch 33/50 - Train loss: 0.0204 - Val loss: 0.1724 - Val accuracy: 0.9495 - LR: 0.000034
# Epoch 34/50 - Train loss: 0.0200 - Val loss: 0.1660 - Val accuracy: 0.9486 - LR: 0.000032
# Epoch 35/50 - Train loss: 0.0180 - Val loss: 0.1530 - Val accuracy: 0.9495 - LR: 0.000030
# Epoch 36/50 - Train loss: 0.0158 - Val loss: 0.1851 - Val accuracy: 0.9449 - LR: 0.000028
# Epoch 37/50 - Train loss: 0.0134 - Val loss: 0.1604 - Val accuracy: 0.9477 - LR: 0.000026
# Epoch 38/50 - Train loss: 0.0141 - Val loss: 0.1628 - Val accuracy: 0.9495 - LR: 0.000024
# Epoch 39/50 - Train loss: 0.0132 - Val loss: 0.1604 - Val accuracy: 0.9504 - LR: 0.000022
# Epoch 40/50 - Train loss: 0.0137 - Val loss: 0.1628 - Val accuracy: 0.9504 - LR: 0.000020
# Epoch 41/50 - Train loss: 0.0145 - Val loss: 0.1599 - Val accuracy: 0.9477 - LR: 0.000018
# Epoch 42/50 - Train loss: 0.0141 - Val loss: 0.1674 - Val accuracy: 0.9504 - LR: 0.000016
# Epoch 43/50 - Train loss: 0.0123 - Val loss: 0.1611 - Val accuracy: 0.9504 - LR: 0.000014
# Epoch 44/50 - Train loss: 0.0110 - Val loss: 0.1688 - Val accuracy: 0.9477 - LR: 0.000012
# Epoch 45/50 - Train loss: 0.0121 - Val loss: 0.1626 - Val accuracy: 0.9495 - LR: 0.000010
# Epoch 46/50 - Train loss: 0.0205 - Val loss: 0.1614 - Val accuracy: 0.9495 - LR: 0.000008
# Epoch 47/50 - Train loss: 0.0124 - Val loss: 0.1629 - Val accuracy: 0.9495 - LR: 0.000006
# Epoch 48/50 - Train loss: 0.0173 - Val loss: 0.1677 - Val accuracy: 0.9495 - LR: 0.000004
# Epoch 49/50 - Train loss: 0.0114 - Val loss: 0.1656 - Val accuracy: 0.9486 - LR: 0.000002
# Epoch 50/50 - Train loss: 0.0113 - Val loss: 0.1656 - Val accuracy: 0.9513 - LR: 0.000000
#
# Best epoch: 50 - Best val accuracy: 0.9513 - Best val loss: 0.1656
#
# RUN -> ['WAL', 'CLD', 'CLU']: 0.79
#
#
# Epoch 1/50 - Train loss: 0.4920 - Val loss: 0.2859 - Val accuracy: 0.8940 - LR: 0.000098
# Epoch 2/50 - Train loss: 0.2323 - Val loss: 0.1704 - Val accuracy: 0.9429 - LR: 0.000096
# Epoch 3/50 - Train loss: 0.1582 - Val loss: 0.1462 - Val accuracy: 0.9519 - LR: 0.000094
# Epoch 4/50 - Train loss: 0.1289 - Val loss: 0.1153 - Val accuracy: 0.9641 - LR: 0.000092
# Epoch 5/50 - Train loss: 0.1042 - Val loss: 0.0999 - Val accuracy: 0.9674 - LR: 0.000090
# Epoch 6/50 - Train loss: 0.0847 - Val loss: 0.0874 - Val accuracy: 0.9731 - LR: 0.000088
# Epoch 7/50 - Train loss: 0.0731 - Val loss: 0.0859 - Val accuracy: 0.9682 - LR: 0.000086
# Epoch 8/50 - Train loss: 0.0688 - Val loss: 0.0805 - Val accuracy: 0.9715 - LR: 0.000084
# Epoch 9/50 - Train loss: 0.0620 - Val loss: 0.0847 - Val accuracy: 0.9698 - LR: 0.000082
# Epoch 10/50 - Train loss: 0.0533 - Val loss: 0.0733 - Val accuracy: 0.9755 - LR: 0.000080
# Epoch 11/50 - Train loss: 0.0477 - Val loss: 0.0734 - Val accuracy: 0.9731 - LR: 0.000078
# Epoch 12/50 - Train loss: 0.0400 - Val loss: 0.0719 - Val accuracy: 0.9747 - LR: 0.000076
# Epoch 13/50 - Train loss: 0.0389 - Val loss: 0.0680 - Val accuracy: 0.9780 - LR: 0.000074
# Epoch 14/50 - Train loss: 0.0394 - Val loss: 0.0652 - Val accuracy: 0.9796 - LR: 0.000072
# Epoch 15/50 - Train loss: 0.0324 - Val loss: 0.0670 - Val accuracy: 0.9788 - LR: 0.000070
# Epoch 16/50 - Train loss: 0.0276 - Val loss: 0.0693 - Val accuracy: 0.9763 - LR: 0.000068
# Epoch 17/50 - Train loss: 0.0270 - Val loss: 0.0682 - Val accuracy: 0.9804 - LR: 0.000066
# Epoch 18/50 - Train loss: 0.0291 - Val loss: 0.0670 - Val accuracy: 0.9788 - LR: 0.000064
# Epoch 19/50 - Train loss: 0.0189 - Val loss: 0.0691 - Val accuracy: 0.9796 - LR: 0.000062
# Epoch 20/50 - Train loss: 0.0211 - Val loss: 0.0656 - Val accuracy: 0.9780 - LR: 0.000060
# Epoch 21/50 - Train loss: 0.0164 - Val loss: 0.0659 - Val accuracy: 0.9796 - LR: 0.000058
# Epoch 22/50 - Train loss: 0.0157 - Val loss: 0.0682 - Val accuracy: 0.9772 - LR: 0.000056
# Epoch 23/50 - Train loss: 0.0146 - Val loss: 0.0682 - Val accuracy: 0.9788 - LR: 0.000054
# Epoch 24/50 - Train loss: 0.0138 - Val loss: 0.0661 - Val accuracy: 0.9780 - LR: 0.000052
# Epoch 25/50 - Train loss: 0.0143 - Val loss: 0.0706 - Val accuracy: 0.9796 - LR: 0.000050
# Epoch 26/50 - Train loss: 0.0111 - Val loss: 0.0639 - Val accuracy: 0.9796 - LR: 0.000048
# Epoch 27/50 - Train loss: 0.0108 - Val loss: 0.0711 - Val accuracy: 0.9780 - LR: 0.000046
# Epoch 28/50 - Train loss: 0.0117 - Val loss: 0.0640 - Val accuracy: 0.9796 - LR: 0.000044
# Epoch 29/50 - Train loss: 0.0102 - Val loss: 0.0692 - Val accuracy: 0.9772 - LR: 0.000042
# Epoch 30/50 - Train loss: 0.0106 - Val loss: 0.0670 - Val accuracy: 0.9796 - LR: 0.000040
# Epoch 31/50 - Train loss: 0.0087 - Val loss: 0.0676 - Val accuracy: 0.9796 - LR: 0.000038
# Epoch 32/50 - Train loss: 0.0067 - Val loss: 0.0687 - Val accuracy: 0.9788 - LR: 0.000036
# Epoch 33/50 - Train loss: 0.0084 - Val loss: 0.0690 - Val accuracy: 0.9780 - LR: 0.000034
# Epoch 34/50 - Train loss: 0.0074 - Val loss: 0.0721 - Val accuracy: 0.9796 - LR: 0.000032
# Epoch 35/50 - Train loss: 0.0063 - Val loss: 0.0669 - Val accuracy: 0.9780 - LR: 0.000030
# Epoch 36/50 - Train loss: 0.0079 - Val loss: 0.0683 - Val accuracy: 0.9788 - LR: 0.000028
# Epoch 37/50 - Train loss: 0.0070 - Val loss: 0.0701 - Val accuracy: 0.9772 - LR: 0.000026
# Epoch 38/50 - Train loss: 0.0055 - Val loss: 0.0696 - Val accuracy: 0.9780 - LR: 0.000024
# Epoch 39/50 - Train loss: 0.0064 - Val loss: 0.0696 - Val accuracy: 0.9772 - LR: 0.000022
# Epoch 40/50 - Train loss: 0.0057 - Val loss: 0.0687 - Val accuracy: 0.9788 - LR: 0.000020
# Epoch 41/50 - Train loss: 0.0046 - Val loss: 0.0708 - Val accuracy: 0.9796 - LR: 0.000018
# Epoch 42/50 - Train loss: 0.0052 - Val loss: 0.0675 - Val accuracy: 0.9788 - LR: 0.000016
# Epoch 43/50 - Train loss: 0.0054 - Val loss: 0.0701 - Val accuracy: 0.9788 - LR: 0.000014
# Epoch 44/50 - Train loss: 0.0057 - Val loss: 0.0707 - Val accuracy: 0.9788 - LR: 0.000012
# Epoch 45/50 - Train loss: 0.0049 - Val loss: 0.0729 - Val accuracy: 0.9788 - LR: 0.000010
# Epoch 46/50 - Train loss: 0.0044 - Val loss: 0.0725 - Val accuracy: 0.9780 - LR: 0.000008
# Epoch 47/50 - Train loss: 0.0048 - Val loss: 0.0709 - Val accuracy: 0.9788 - LR: 0.000006
# Epoch 48/50 - Train loss: 0.0050 - Val loss: 0.0747 - Val accuracy: 0.9772 - LR: 0.000004
# Epoch 49/50 - Train loss: 0.0046 - Val loss: 0.0735 - Val accuracy: 0.9780 - LR: 0.000002
# Epoch 50/50 - Train loss: 0.0048 - Val loss: 0.0721 - Val accuracy: 0.9788 - LR: 0.000000
#
# Best epoch: 17 - Best val accuracy: 0.9804 - Best val loss: 0.0682
#
# CLD -> ['WAL', 'RUN', 'CLU']: 0.91
#
#
# Epoch 1/50 - Train loss: 0.5411 - Val loss: 0.3219 - Val accuracy: 0.8847 - LR: 0.000098
# Epoch 2/50 - Train loss: 0.2452 - Val loss: 0.1662 - Val accuracy: 0.9500 - LR: 0.000096
# Epoch 3/50 - Train loss: 0.1522 - Val loss: 0.1293 - Val accuracy: 0.9517 - LR: 0.000094
# Epoch 4/50 - Train loss: 0.1143 - Val loss: 0.1030 - Val accuracy: 0.9610 - LR: 0.000092
# Epoch 5/50 - Train loss: 0.0938 - Val loss: 0.0907 - Val accuracy: 0.9653 - LR: 0.000090
# Epoch 6/50 - Train loss: 0.0803 - Val loss: 0.0827 - Val accuracy: 0.9686 - LR: 0.000088
# Epoch 7/50 - Train loss: 0.0693 - Val loss: 0.0769 - Val accuracy: 0.9703 - LR: 0.000086
# Epoch 8/50 - Train loss: 0.0602 - Val loss: 0.0709 - Val accuracy: 0.9712 - LR: 0.000084
# Epoch 9/50 - Train loss: 0.0570 - Val loss: 0.0713 - Val accuracy: 0.9712 - LR: 0.000082
# Epoch 10/50 - Train loss: 0.0496 - Val loss: 0.0712 - Val accuracy: 0.9703 - LR: 0.000080
# Epoch 11/50 - Train loss: 0.0510 - Val loss: 0.0654 - Val accuracy: 0.9754 - LR: 0.000078
# Epoch 12/50 - Train loss: 0.0463 - Val loss: 0.0654 - Val accuracy: 0.9712 - LR: 0.000076
# Epoch 13/50 - Train loss: 0.0403 - Val loss: 0.0667 - Val accuracy: 0.9720 - LR: 0.000074
# Epoch 14/50 - Train loss: 0.0372 - Val loss: 0.0682 - Val accuracy: 0.9703 - LR: 0.000072
# Epoch 15/50 - Train loss: 0.0346 - Val loss: 0.0613 - Val accuracy: 0.9780 - LR: 0.000070
# Epoch 16/50 - Train loss: 0.0316 - Val loss: 0.0623 - Val accuracy: 0.9746 - LR: 0.000068
# Epoch 17/50 - Train loss: 0.0251 - Val loss: 0.0591 - Val accuracy: 0.9754 - LR: 0.000066
# Epoch 18/50 - Train loss: 0.0243 - Val loss: 0.0658 - Val accuracy: 0.9729 - LR: 0.000064
# Epoch 19/50 - Train loss: 0.0218 - Val loss: 0.0621 - Val accuracy: 0.9737 - LR: 0.000062
# Epoch 20/50 - Train loss: 0.0198 - Val loss: 0.0628 - Val accuracy: 0.9737 - LR: 0.000060
# Epoch 21/50 - Train loss: 0.0169 - Val loss: 0.0609 - Val accuracy: 0.9746 - LR: 0.000058
# Epoch 22/50 - Train loss: 0.0175 - Val loss: 0.0630 - Val accuracy: 0.9729 - LR: 0.000056
# Epoch 23/50 - Train loss: 0.0141 - Val loss: 0.0637 - Val accuracy: 0.9780 - LR: 0.000054
# Epoch 24/50 - Train loss: 0.0164 - Val loss: 0.0775 - Val accuracy: 0.9720 - LR: 0.000052
# Epoch 25/50 - Train loss: 0.0129 - Val loss: 0.0584 - Val accuracy: 0.9780 - LR: 0.000050
# Epoch 26/50 - Train loss: 0.0143 - Val loss: 0.0737 - Val accuracy: 0.9746 - LR: 0.000048
# Epoch 27/50 - Train loss: 0.0088 - Val loss: 0.0633 - Val accuracy: 0.9754 - LR: 0.000046
# Epoch 28/50 - Train loss: 0.0103 - Val loss: 0.0591 - Val accuracy: 0.9780 - LR: 0.000044
# Epoch 29/50 - Train loss: 0.0102 - Val loss: 0.0591 - Val accuracy: 0.9797 - LR: 0.000042
# Epoch 30/50 - Train loss: 0.0092 - Val loss: 0.0669 - Val accuracy: 0.9746 - LR: 0.000040
# Epoch 31/50 - Train loss: 0.0100 - Val loss: 0.0603 - Val accuracy: 0.9780 - LR: 0.000038
# Epoch 32/50 - Train loss: 0.0088 - Val loss: 0.0604 - Val accuracy: 0.9771 - LR: 0.000036
# Epoch 33/50 - Train loss: 0.0094 - Val loss: 0.0601 - Val accuracy: 0.9780 - LR: 0.000034
# Epoch 34/50 - Train loss: 0.0071 - Val loss: 0.0600 - Val accuracy: 0.9788 - LR: 0.000032
# Epoch 35/50 - Train loss: 0.0060 - Val loss: 0.0657 - Val accuracy: 0.9729 - LR: 0.000030
# Epoch 36/50 - Train loss: 0.0065 - Val loss: 0.0633 - Val accuracy: 0.9771 - LR: 0.000028
# Epoch 37/50 - Train loss: 0.0069 - Val loss: 0.0639 - Val accuracy: 0.9771 - LR: 0.000026
# Epoch 38/50 - Train loss: 0.0054 - Val loss: 0.0649 - Val accuracy: 0.9763 - LR: 0.000024
# Epoch 39/50 - Train loss: 0.0055 - Val loss: 0.0628 - Val accuracy: 0.9763 - LR: 0.000022
# Epoch 40/50 - Train loss: 0.0050 - Val loss: 0.0662 - Val accuracy: 0.9746 - LR: 0.000020
# Epoch 41/50 - Train loss: 0.0055 - Val loss: 0.0669 - Val accuracy: 0.9746 - LR: 0.000018
# Epoch 42/50 - Train loss: 0.0041 - Val loss: 0.0644 - Val accuracy: 0.9771 - LR: 0.000016
# Epoch 43/50 - Train loss: 0.0035 - Val loss: 0.0628 - Val accuracy: 0.9780 - LR: 0.000014
# Epoch 44/50 - Train loss: 0.0042 - Val loss: 0.0654 - Val accuracy: 0.9763 - LR: 0.000012
# Epoch 45/50 - Train loss: 0.0043 - Val loss: 0.0643 - Val accuracy: 0.9780 - LR: 0.000010
# Epoch 46/50 - Train loss: 0.0049 - Val loss: 0.0637 - Val accuracy: 0.9763 - LR: 0.000008
# Epoch 47/50 - Train loss: 0.0039 - Val loss: 0.0647 - Val accuracy: 0.9780 - LR: 0.000006
# Epoch 48/50 - Train loss: 0.0052 - Val loss: 0.0645 - Val accuracy: 0.9771 - LR: 0.000004
# Epoch 49/50 - Train loss: 0.0038 - Val loss: 0.0663 - Val accuracy: 0.9763 - LR: 0.000002
# Epoch 50/50 - Train loss: 0.0041 - Val loss: 0.0651 - Val accuracy: 0.9771 - LR: 0.000000
#
# Best epoch: 29 - Best val accuracy: 0.9797 - Best val loss: 0.0591
#
# CLU -> ['WAL', 'RUN', 'CLD']: 0.92
#
#
# Mean accuracy: 0.90

# %%
dataset = 'cwru'

if dataset == 'realworld':
    dataset_name = 'realworld_128_3ch_4cl'
    num_df_domains = 10
    num_dp_domains = 5
    num_classes = 4
    class_names = ['WAL', 'RUN', 'CLD', 'CLU']

elif dataset == 'cwru':
    dataset_name = 'cwru_256_3ch_5cl'
    num_df_domains = 4
    num_dp_domains = 4
    num_classes = 5
    class_names = ['IR', 'Ball', 'OR_centred', 'OR_orthogonal', 'OR_opposite']

classes_dict = {clss: i for i, clss in enumerate(class_names)}

accs = []

for src_class in class_names:
    trg_classes = [clss for clss in class_names if clss != src_class]

    x_df = []
    y_df = []
    k_df = []

    x_dp = []
    y_dp = []
    k_dp = []

    for trg_class in trg_classes:
        x_df_, y_df_, k_df_ = get_df_data(dataset_name, classes_dict[trg_class], num_df_domains)
        x_dp_, y_dp_, k_dp_ = get_dp_data(dataset_name, classes_dict[trg_class], num_df_domains)

        x_df.append(x_df_)
        y_df.append(y_df_)
        k_df.append(k_df_)

        x_dp.append(x_dp_)
        y_dp.append(y_dp_)
        k_dp.append(k_dp_)

    x_df = np.concatenate(x_df, axis=0)
    y_df = np.concatenate(y_df, axis=0)
    k_df = np.concatenate(k_df, axis=0)

    x_dp = np.concatenate(x_dp, axis=0)
    y_dp = np.concatenate(y_dp, axis=0)
    k_dp = np.concatenate(k_dp, axis=0)

    acc, loss = calculate_tstr_score(x_df, y_df, x_dp, y_dp)
    accs.append(acc)

    print(f'{src_class} -> {trg_classes}: {acc:.2f}\n\n')

print(f'Mean accuracy: {np.mean(accs):.2f}')
# Out:
# Epoch 1/50 - Train loss: 0.4808 - Val loss: 0.3004 - Val accuracy: 0.8123 - LR: 0.000098
# Epoch 2/50 - Train loss: 0.0928 - Val loss: 1.3312 - Val accuracy: 0.7354 - LR: 0.000096
# Epoch 3/50 - Train loss: 0.0282 - Val loss: 0.2709 - Val accuracy: 0.8760 - LR: 0.000094
# Epoch 4/50 - Train loss: 0.0148 - Val loss: 0.0969 - Val accuracy: 0.9602 - LR: 0.000092
# Epoch 5/50 - Train loss: 0.0135 - Val loss: 0.2875 - Val accuracy: 0.8840 - LR: 0.000090
# Epoch 6/50 - Train loss: 0.0090 - Val loss: 0.0612 - Val accuracy: 0.9748 - LR: 0.000088
# Epoch 7/50 - Train loss: 0.0057 - Val loss: 0.0342 - Val accuracy: 0.9887 - LR: 0.000086
# Epoch 8/50 - Train loss: 0.0047 - Val loss: 0.0023 - Val accuracy: 1.0000 - LR: 0.000084
# Epoch 9/50 - Train loss: 0.0045 - Val loss: 0.0029 - Val accuracy: 0.9993 - LR: 0.000082
# Epoch 10/50 - Train loss: 0.0050 - Val loss: 0.0276 - Val accuracy: 0.9920 - LR: 0.000080
# Epoch 11/50 - Train loss: 0.0037 - Val loss: 0.0015 - Val accuracy: 1.0000 - LR: 0.000078
# Epoch 12/50 - Train loss: 0.0025 - Val loss: 0.0012 - Val accuracy: 1.0000 - LR: 0.000076
# Epoch 13/50 - Train loss: 0.0031 - Val loss: 0.0047 - Val accuracy: 0.9973 - LR: 0.000074
# Epoch 14/50 - Train loss: 0.0021 - Val loss: 0.0007 - Val accuracy: 1.0000 - LR: 0.000072
# Epoch 15/50 - Train loss: 0.0019 - Val loss: 0.0063 - Val accuracy: 0.9980 - LR: 0.000070
# Epoch 16/50 - Train loss: 0.0030 - Val loss: 0.0014 - Val accuracy: 1.0000 - LR: 0.000068
# Epoch 17/50 - Train loss: 0.0015 - Val loss: 0.0004 - Val accuracy: 1.0000 - LR: 0.000066
# Epoch 18/50 - Train loss: 0.0012 - Val loss: 0.0010 - Val accuracy: 1.0000 - LR: 0.000064
# Epoch 19/50 - Train loss: 0.0019 - Val loss: 0.0089 - Val accuracy: 0.9967 - LR: 0.000062
# Epoch 20/50 - Train loss: 0.0025 - Val loss: 0.0005 - Val accuracy: 1.0000 - LR: 0.000060
# Epoch 21/50 - Train loss: 0.0013 - Val loss: 0.0004 - Val accuracy: 1.0000 - LR: 0.000058
# Epoch 22/50 - Train loss: 0.0007 - Val loss: 0.0004 - Val accuracy: 1.0000 - LR: 0.000056
# Epoch 23/50 - Train loss: 0.0008 - Val loss: 0.0003 - Val accuracy: 1.0000 - LR: 0.000054
# Epoch 24/50 - Train loss: 0.0015 - Val loss: 0.0004 - Val accuracy: 1.0000 - LR: 0.000052
# Epoch 25/50 - Train loss: 0.0018 - Val loss: 0.0003 - Val accuracy: 1.0000 - LR: 0.000050
# Epoch 26/50 - Train loss: 0.0008 - Val loss: 0.0021 - Val accuracy: 0.9987 - LR: 0.000048
# Epoch 27/50 - Train loss: 0.0006 - Val loss: 0.0002 - Val accuracy: 1.0000 - LR: 0.000046
# Epoch 28/50 - Train loss: 0.0018 - Val loss: 0.0026 - Val accuracy: 1.0000 - LR: 0.000044
# Epoch 29/50 - Train loss: 0.0028 - Val loss: 0.0002 - Val accuracy: 1.0000 - LR: 0.000042
# Epoch 30/50 - Train loss: 0.0004 - Val loss: 0.0002 - Val accuracy: 1.0000 - LR: 0.000040
# Epoch 31/50 - Train loss: 0.0006 - Val loss: 0.0004 - Val accuracy: 1.0000 - LR: 0.000038
# Epoch 32/50 - Train loss: 0.0006 - Val loss: 0.0002 - Val accuracy: 1.0000 - LR: 0.000036
# Epoch 33/50 - Train loss: 0.0012 - Val loss: 0.0002 - Val accuracy: 1.0000 - LR: 0.000034
# Epoch 34/50 - Train loss: 0.0210 - Val loss: 0.0002 - Val accuracy: 1.0000 - LR: 0.000032
# Epoch 35/50 - Train loss: 0.0021 - Val loss: 0.0002 - Val accuracy: 1.0000 - LR: 0.000030
# Epoch 36/50 - Train loss: 0.0008 - Val loss: 0.0003 - Val accuracy: 1.0000 - LR: 0.000028
# Epoch 37/50 - Train loss: 0.0006 - Val loss: 0.0002 - Val accuracy: 1.0000 - LR: 0.000026
# Epoch 38/50 - Train loss: 0.0006 - Val loss: 0.0002 - Val accuracy: 1.0000 - LR: 0.000024
# Epoch 39/50 - Train loss: 0.0005 - Val loss: 0.0002 - Val accuracy: 1.0000 - LR: 0.000022
# Epoch 40/50 - Train loss: 0.0006 - Val loss: 0.0002 - Val accuracy: 1.0000 - LR: 0.000020
# Epoch 41/50 - Train loss: 0.0004 - Val loss: 0.0002 - Val accuracy: 1.0000 - LR: 0.000018
# Epoch 42/50 - Train loss: 0.0005 - Val loss: 0.0006 - Val accuracy: 1.0000 - LR: 0.000016
# Epoch 43/50 - Train loss: 0.0005 - Val loss: 0.0002 - Val accuracy: 1.0000 - LR: 0.000014
# Epoch 44/50 - Train loss: 0.0008 - Val loss: 0.0002 - Val accuracy: 1.0000 - LR: 0.000012
# Epoch 45/50 - Train loss: 0.0005 - Val loss: 0.0002 - Val accuracy: 1.0000 - LR: 0.000010
# Epoch 46/50 - Train loss: 0.0005 - Val loss: 0.0002 - Val accuracy: 1.0000 - LR: 0.000008
# Epoch 47/50 - Train loss: 0.0004 - Val loss: 0.0002 - Val accuracy: 1.0000 - LR: 0.000006
# Epoch 48/50 - Train loss: 0.0031 - Val loss: 0.0002 - Val accuracy: 1.0000 - LR: 0.000004
# Epoch 49/50 - Train loss: 0.0004 - Val loss: 0.0007 - Val accuracy: 1.0000 - LR: 0.000002
# Epoch 50/50 - Train loss: 0.0007 - Val loss: 0.0006 - Val accuracy: 1.0000 - LR: 0.000000
#
# Best epoch: 8 - Best val accuracy: 1.0000 - Best val loss: 0.0023
#
# IR -> ['Ball', 'OR_centred', 'OR_orthogonal', 'OR_opposite']: 0.37
#
#
# Epoch 1/50 - Train loss: 0.3975 - Val loss: 0.0327 - Val accuracy: 0.9967 - LR: 0.000098
# Epoch 2/50 - Train loss: 0.0161 - Val loss: 0.0059 - Val accuracy: 1.0000 - LR: 0.000096
# Epoch 3/50 - Train loss: 0.0059 - Val loss: 0.0032 - Val accuracy: 1.0000 - LR: 0.000094
# Epoch 4/50 - Train loss: 0.0027 - Val loss: 0.0014 - Val accuracy: 1.0000 - LR: 0.000092
# Epoch 5/50 - Train loss: 0.0020 - Val loss: 0.0011 - Val accuracy: 1.0000 - LR: 0.000090
# Epoch 6/50 - Train loss: 0.0014 - Val loss: 0.0007 - Val accuracy: 1.0000 - LR: 0.000088
# Epoch 7/50 - Train loss: 0.0010 - Val loss: 0.0005 - Val accuracy: 1.0000 - LR: 0.000086
# Epoch 8/50 - Train loss: 0.0007 - Val loss: 0.0004 - Val accuracy: 1.0000 - LR: 0.000084
# Epoch 9/50 - Train loss: 0.0005 - Val loss: 0.0003 - Val accuracy: 1.0000 - LR: 0.000082
# Epoch 10/50 - Train loss: 0.0004 - Val loss: 0.0002 - Val accuracy: 1.0000 - LR: 0.000080
# Epoch 11/50 - Train loss: 0.0004 - Val loss: 0.0002 - Val accuracy: 1.0000 - LR: 0.000078
# Epoch 12/50 - Train loss: 0.0003 - Val loss: 0.0002 - Val accuracy: 1.0000 - LR: 0.000076
# Epoch 13/50 - Train loss: 0.0002 - Val loss: 0.0001 - Val accuracy: 1.0000 - LR: 0.000074
# Epoch 14/50 - Train loss: 0.0003 - Val loss: 0.0001 - Val accuracy: 1.0000 - LR: 0.000072
# Epoch 15/50 - Train loss: 0.0002 - Val loss: 0.0001 - Val accuracy: 1.0000 - LR: 0.000070
# Epoch 16/50 - Train loss: 0.0002 - Val loss: 0.0001 - Val accuracy: 1.0000 - LR: 0.000068
# Epoch 17/50 - Train loss: 0.0001 - Val loss: 0.0001 - Val accuracy: 1.0000 - LR: 0.000066
# Epoch 18/50 - Train loss: 0.0001 - Val loss: 0.0001 - Val accuracy: 1.0000 - LR: 0.000064
# Epoch 19/50 - Train loss: 0.0001 - Val loss: 0.0001 - Val accuracy: 1.0000 - LR: 0.000062
# Epoch 20/50 - Train loss: 0.0001 - Val loss: 0.0000 - Val accuracy: 1.0000 - LR: 0.000060
# Epoch 21/50 - Train loss: 0.0001 - Val loss: 0.0000 - Val accuracy: 1.0000 - LR: 0.000058
# Epoch 22/50 - Train loss: 0.0001 - Val loss: 0.0000 - Val accuracy: 1.0000 - LR: 0.000056
# Epoch 23/50 - Train loss: 0.0001 - Val loss: 0.0000 - Val accuracy: 1.0000 - LR: 0.000054
# Epoch 24/50 - Train loss: 0.0001 - Val loss: 0.0000 - Val accuracy: 1.0000 - LR: 0.000052
# Epoch 25/50 - Train loss: 0.0001 - Val loss: 0.0000 - Val accuracy: 1.0000 - LR: 0.000050
# Epoch 26/50 - Train loss: 0.0001 - Val loss: 0.0000 - Val accuracy: 1.0000 - LR: 0.000048
# Epoch 27/50 - Train loss: 0.0001 - Val loss: 0.0000 - Val accuracy: 1.0000 - LR: 0.000046
# Epoch 28/50 - Train loss: 0.0001 - Val loss: 0.0000 - Val accuracy: 1.0000 - LR: 0.000044
# Epoch 29/50 - Train loss: 0.0001 - Val loss: 0.0000 - Val accuracy: 1.0000 - LR: 0.000042
# Epoch 30/50 - Train loss: 0.0001 - Val loss: 0.0000 - Val accuracy: 1.0000 - LR: 0.000040
# Epoch 31/50 - Train loss: 0.0000 - Val loss: 0.0000 - Val accuracy: 1.0000 - LR: 0.000038
# Epoch 32/50 - Train loss: 0.0000 - Val loss: 0.0000 - Val accuracy: 1.0000 - LR: 0.000036
# Epoch 33/50 - Train loss: 0.0000 - Val loss: 0.0000 - Val accuracy: 1.0000 - LR: 0.000034
# Epoch 34/50 - Train loss: 0.0000 - Val loss: 0.0000 - Val accuracy: 1.0000 - LR: 0.000032
# Epoch 35/50 - Train loss: 0.0000 - Val loss: 0.0000 - Val accuracy: 1.0000 - LR: 0.000030
# Epoch 36/50 - Train loss: 0.0000 - Val loss: 0.0000 - Val accuracy: 1.0000 - LR: 0.000028
# Epoch 37/50 - Train loss: 0.0000 - Val loss: 0.0000 - Val accuracy: 1.0000 - LR: 0.000026
# Epoch 38/50 - Train loss: 0.0000 - Val loss: 0.0000 - Val accuracy: 1.0000 - LR: 0.000024
# Epoch 39/50 - Train loss: 0.0000 - Val loss: 0.0000 - Val accuracy: 1.0000 - LR: 0.000022
# Epoch 40/50 - Train loss: 0.0000 - Val loss: 0.0000 - Val accuracy: 1.0000 - LR: 0.000020
# Epoch 41/50 - Train loss: 0.0000 - Val loss: 0.0000 - Val accuracy: 1.0000 - LR: 0.000018
# Epoch 42/50 - Train loss: 0.0000 - Val loss: 0.0000 - Val accuracy: 1.0000 - LR: 0.000016
# Epoch 43/50 - Train loss: 0.0000 - Val loss: 0.0000 - Val accuracy: 1.0000 - LR: 0.000014
# Epoch 44/50 - Train loss: 0.0000 - Val loss: 0.0000 - Val accuracy: 1.0000 - LR: 0.000012
# Epoch 45/50 - Train loss: 0.0005 - Val loss: 0.0000 - Val accuracy: 1.0000 - LR: 0.000010
# Epoch 46/50 - Train loss: 0.0000 - Val loss: 0.0000 - Val accuracy: 1.0000 - LR: 0.000008
# Epoch 47/50 - Train loss: 0.0000 - Val loss: 0.0000 - Val accuracy: 1.0000 - LR: 0.000006
# Epoch 48/50 - Train loss: 0.0000 - Val loss: 0.0000 - Val accuracy: 1.0000 - LR: 0.000004
# Epoch 49/50 - Train loss: 0.0000 - Val loss: 0.0000 - Val accuracy: 1.0000 - LR: 0.000002
# Epoch 50/50 - Train loss: 0.0000 - Val loss: 0.0000 - Val accuracy: 1.0000 - LR: 0.000000
#
# Best epoch: 2 - Best val accuracy: 1.0000 - Best val loss: 0.0059
#
# Ball -> ['IR', 'OR_centred', 'OR_orthogonal', 'OR_opposite']: 0.34
#
#
# Epoch 1/50 - Train loss: 0.4685 - Val loss: 0.1795 - Val accuracy: 0.9443 - LR: 0.000098
# Epoch 2/50 - Train loss: 0.1121 - Val loss: 0.2888 - Val accuracy: 0.8840 - LR: 0.000096
# Epoch 3/50 - Train loss: 0.0379 - Val loss: 0.0251 - Val accuracy: 0.9954 - LR: 0.000094
# Epoch 4/50 - Train loss: 0.0178 - Val loss: 0.0178 - Val accuracy: 0.9920 - LR: 0.000092
# Epoch 5/50 - Train loss: 0.0120 - Val loss: 0.0036 - Val accuracy: 1.0000 - LR: 0.000090
# Epoch 6/50 - Train loss: 0.0101 - Val loss: 0.1810 - Val accuracy: 0.9191 - LR: 0.000088
# Epoch 7/50 - Train loss: 0.0051 - Val loss: 0.0012 - Val accuracy: 1.0000 - LR: 0.000086
# Epoch 8/50 - Train loss: 0.0044 - Val loss: 0.0035 - Val accuracy: 1.0000 - LR: 0.000084
# Epoch 9/50 - Train loss: 0.0037 - Val loss: 0.0014 - Val accuracy: 1.0000 - LR: 0.000082
# Epoch 10/50 - Train loss: 0.0032 - Val loss: 0.0415 - Val accuracy: 0.9808 - LR: 0.000080
# Epoch 11/50 - Train loss: 0.0027 - Val loss: 0.0007 - Val accuracy: 1.0000 - LR: 0.000078
# Epoch 12/50 - Train loss: 0.0025 - Val loss: 0.0368 - Val accuracy: 0.9821 - LR: 0.000076
# Epoch 13/50 - Train loss: 0.0014 - Val loss: 0.0003 - Val accuracy: 1.0000 - LR: 0.000074
# Epoch 14/50 - Train loss: 0.0011 - Val loss: 0.0003 - Val accuracy: 1.0000 - LR: 0.000072
# Epoch 15/50 - Train loss: 0.0010 - Val loss: 0.0003 - Val accuracy: 1.0000 - LR: 0.000070
# Epoch 16/50 - Train loss: 0.0008 - Val loss: 0.0003 - Val accuracy: 1.0000 - LR: 0.000068
# Epoch 17/50 - Train loss: 0.0014 - Val loss: 0.0007 - Val accuracy: 1.0000 - LR: 0.000066
# Epoch 18/50 - Train loss: 0.0007 - Val loss: 0.0002 - Val accuracy: 1.0000 - LR: 0.000064
# Epoch 19/50 - Train loss: 0.0007 - Val loss: 0.0004 - Val accuracy: 1.0000 - LR: 0.000062
# Epoch 20/50 - Train loss: 0.0007 - Val loss: 0.0001 - Val accuracy: 1.0000 - LR: 0.000060
# Epoch 21/50 - Train loss: 0.0010 - Val loss: 0.0019 - Val accuracy: 0.9993 - LR: 0.000058
# Epoch 22/50 - Train loss: 0.0022 - Val loss: 0.0001 - Val accuracy: 1.0000 - LR: 0.000056
# Epoch 23/50 - Train loss: 0.0010 - Val loss: 0.0002 - Val accuracy: 1.0000 - LR: 0.000054
# Epoch 24/50 - Train loss: 0.0006 - Val loss: 0.0004 - Val accuracy: 1.0000 - LR: 0.000052
# Epoch 25/50 - Train loss: 0.0004 - Val loss: 0.0001 - Val accuracy: 1.0000 - LR: 0.000050
# Epoch 26/50 - Train loss: 0.0003 - Val loss: 0.0002 - Val accuracy: 1.0000 - LR: 0.000048
# Epoch 27/50 - Train loss: 0.0006 - Val loss: 0.0007 - Val accuracy: 1.0000 - LR: 0.000046
# Epoch 28/50 - Train loss: 0.0004 - Val loss: 0.0001 - Val accuracy: 1.0000 - LR: 0.000044
# Epoch 29/50 - Train loss: 0.0006 - Val loss: 0.0008 - Val accuracy: 1.0000 - LR: 0.000042
# Epoch 30/50 - Train loss: 0.0002 - Val loss: 0.0000 - Val accuracy: 1.0000 - LR: 0.000040
# Epoch 31/50 - Train loss: 0.0005 - Val loss: 0.0001 - Val accuracy: 1.0000 - LR: 0.000038
# Epoch 32/50 - Train loss: 0.0005 - Val loss: 0.0001 - Val accuracy: 1.0000 - LR: 0.000036
# Epoch 33/50 - Train loss: 0.0006 - Val loss: 0.0001 - Val accuracy: 1.0000 - LR: 0.000034
# Epoch 34/50 - Train loss: 0.0007 - Val loss: 0.0001 - Val accuracy: 1.0000 - LR: 0.000032
# Epoch 35/50 - Train loss: 0.0002 - Val loss: 0.0001 - Val accuracy: 1.0000 - LR: 0.000030
# Epoch 36/50 - Train loss: 0.0002 - Val loss: 0.0001 - Val accuracy: 1.0000 - LR: 0.000028
# Epoch 37/50 - Train loss: 0.0005 - Val loss: 0.0000 - Val accuracy: 1.0000 - LR: 0.000026
# Epoch 38/50 - Train loss: 0.0001 - Val loss: 0.0000 - Val accuracy: 1.0000 - LR: 0.000024
# Epoch 39/50 - Train loss: 0.0002 - Val loss: 0.0000 - Val accuracy: 1.0000 - LR: 0.000022
# Epoch 40/50 - Train loss: 0.0094 - Val loss: 0.0001 - Val accuracy: 1.0000 - LR: 0.000020
# Epoch 41/50 - Train loss: 0.0047 - Val loss: 0.0000 - Val accuracy: 1.0000 - LR: 0.000018
# Epoch 42/50 - Train loss: 0.0003 - Val loss: 0.0000 - Val accuracy: 1.0000 - LR: 0.000016
# Epoch 43/50 - Train loss: 0.0003 - Val loss: 0.0000 - Val accuracy: 1.0000 - LR: 0.000014
# Epoch 44/50 - Train loss: 0.0005 - Val loss: 0.0000 - Val accuracy: 1.0000 - LR: 0.000012
# Epoch 45/50 - Train loss: 0.0004 - Val loss: 0.0000 - Val accuracy: 1.0000 - LR: 0.000010
# Epoch 46/50 - Train loss: 0.0003 - Val loss: 0.0000 - Val accuracy: 1.0000 - LR: 0.000008
# Epoch 47/50 - Train loss: 0.0004 - Val loss: 0.0001 - Val accuracy: 1.0000 - LR: 0.000006
# Epoch 48/50 - Train loss: 0.0003 - Val loss: 0.0001 - Val accuracy: 1.0000 - LR: 0.000004
# Epoch 49/50 - Train loss: 0.0001 - Val loss: 0.0000 - Val accuracy: 1.0000 - LR: 0.000002
# Epoch 50/50 - Train loss: 0.0003 - Val loss: 0.0001 - Val accuracy: 1.0000 - LR: 0.000000
#
# Best epoch: 5 - Best val accuracy: 1.0000 - Best val loss: 0.0036
#
# OR_centred -> ['IR', 'Ball', 'OR_orthogonal', 'OR_opposite']: 0.36
#
#
# Epoch 1/50 - Train loss: 0.4907 - Val loss: 0.1498 - Val accuracy: 0.9503 - LR: 0.000098
# Epoch 2/50 - Train loss: 0.0695 - Val loss: 0.0745 - Val accuracy: 0.9715 - LR: 0.000096
# Epoch 3/50 - Train loss: 0.0256 - Val loss: 0.0100 - Val accuracy: 0.9993 - LR: 0.000094
# Epoch 4/50 - Train loss: 0.0118 - Val loss: 0.0716 - Val accuracy: 0.9748 - LR: 0.000092
# Epoch 5/50 - Train loss: 0.0076 - Val loss: 0.0352 - Val accuracy: 0.9881 - LR: 0.000090
# Epoch 6/50 - Train loss: 0.0046 - Val loss: 0.0039 - Val accuracy: 1.0000 - LR: 0.000088
# Epoch 7/50 - Train loss: 0.0030 - Val loss: 0.0051 - Val accuracy: 0.9993 - LR: 0.000086
# Epoch 8/50 - Train loss: 0.0023 - Val loss: 0.0283 - Val accuracy: 0.9894 - LR: 0.000084
# Epoch 9/50 - Train loss: 0.0028 - Val loss: 0.0046 - Val accuracy: 0.9993 - LR: 0.000082
# Epoch 10/50 - Train loss: 0.0014 - Val loss: 0.0033 - Val accuracy: 0.9993 - LR: 0.000080
# Epoch 11/50 - Train loss: 0.0027 - Val loss: 0.0015 - Val accuracy: 1.0000 - LR: 0.000078
# Epoch 12/50 - Train loss: 0.0013 - Val loss: 0.0006 - Val accuracy: 1.0000 - LR: 0.000076
# Epoch 13/50 - Train loss: 0.0014 - Val loss: 0.0007 - Val accuracy: 1.0000 - LR: 0.000074
# Epoch 14/50 - Train loss: 0.0007 - Val loss: 0.0004 - Val accuracy: 1.0000 - LR: 0.000072
# Epoch 15/50 - Train loss: 0.0010 - Val loss: 0.0022 - Val accuracy: 1.0000 - LR: 0.000070
# Epoch 16/50 - Train loss: 0.0013 - Val loss: 0.0019 - Val accuracy: 1.0000 - LR: 0.000068
# Epoch 17/50 - Train loss: 0.0009 - Val loss: 0.0006 - Val accuracy: 1.0000 - LR: 0.000066
# Epoch 18/50 - Train loss: 0.0007 - Val loss: 0.0011 - Val accuracy: 1.0000 - LR: 0.000064
# Epoch 19/50 - Train loss: 0.0007 - Val loss: 0.0002 - Val accuracy: 1.0000 - LR: 0.000062
# Epoch 20/50 - Train loss: 0.0007 - Val loss: 0.0003 - Val accuracy: 1.0000 - LR: 0.000060
# Epoch 21/50 - Train loss: 0.0004 - Val loss: 0.0002 - Val accuracy: 1.0000 - LR: 0.000058
# Epoch 22/50 - Train loss: 0.0002 - Val loss: 0.0002 - Val accuracy: 1.0000 - LR: 0.000056
# Epoch 23/50 - Train loss: 0.0004 - Val loss: 0.0002 - Val accuracy: 1.0000 - LR: 0.000054
# Epoch 24/50 - Train loss: 0.0008 - Val loss: 0.0001 - Val accuracy: 1.0000 - LR: 0.000052
# Epoch 25/50 - Train loss: 0.0004 - Val loss: 0.0047 - Val accuracy: 0.9987 - LR: 0.000050
# Epoch 26/50 - Train loss: 0.0006 - Val loss: 0.0018 - Val accuracy: 1.0000 - LR: 0.000048
# Epoch 27/50 - Train loss: 0.0011 - Val loss: 0.0053 - Val accuracy: 0.9980 - LR: 0.000046
# Epoch 28/50 - Train loss: 0.0004 - Val loss: 0.0001 - Val accuracy: 1.0000 - LR: 0.000044
# Epoch 29/50 - Train loss: 0.0002 - Val loss: 0.0002 - Val accuracy: 1.0000 - LR: 0.000042
# Epoch 30/50 - Train loss: 0.0001 - Val loss: 0.0001 - Val accuracy: 1.0000 - LR: 0.000040
# Epoch 31/50 - Train loss: 0.0002 - Val loss: 0.0001 - Val accuracy: 1.0000 - LR: 0.000038
# Epoch 32/50 - Train loss: 0.0002 - Val loss: 0.0001 - Val accuracy: 1.0000 - LR: 0.000036
# Epoch 33/50 - Train loss: 0.0001 - Val loss: 0.0001 - Val accuracy: 1.0000 - LR: 0.000034
# Epoch 34/50 - Train loss: 0.0003 - Val loss: 0.0004 - Val accuracy: 1.0000 - LR: 0.000032
# Epoch 35/50 - Train loss: 0.0002 - Val loss: 0.0001 - Val accuracy: 1.0000 - LR: 0.000030
# Epoch 36/50 - Train loss: 0.0003 - Val loss: 0.0001 - Val accuracy: 1.0000 - LR: 0.000028
# Epoch 37/50 - Train loss: 0.0002 - Val loss: 0.0001 - Val accuracy: 1.0000 - LR: 0.000026
# Epoch 38/50 - Train loss: 0.0001 - Val loss: 0.0001 - Val accuracy: 1.0000 - LR: 0.000024
# Epoch 39/50 - Train loss: 0.0004 - Val loss: 0.0001 - Val accuracy: 1.0000 - LR: 0.000022
# Epoch 40/50 - Train loss: 0.0001 - Val loss: 0.0002 - Val accuracy: 1.0000 - LR: 0.000020
# Epoch 41/50 - Train loss: 0.0040 - Val loss: 0.0004 - Val accuracy: 1.0000 - LR: 0.000018
# Epoch 42/50 - Train loss: 0.0037 - Val loss: 0.0001 - Val accuracy: 1.0000 - LR: 0.000016
# Epoch 43/50 - Train loss: 0.0002 - Val loss: 0.0001 - Val accuracy: 1.0000 - LR: 0.000014
# Epoch 44/50 - Train loss: 0.0010 - Val loss: 0.0003 - Val accuracy: 1.0000 - LR: 0.000012
# Epoch 45/50 - Train loss: 0.0001 - Val loss: 0.0000 - Val accuracy: 1.0000 - LR: 0.000010
# Epoch 46/50 - Train loss: 0.0002 - Val loss: 0.0001 - Val accuracy: 1.0000 - LR: 0.000008
# Epoch 47/50 - Train loss: 0.0002 - Val loss: 0.0001 - Val accuracy: 1.0000 - LR: 0.000006
# Epoch 48/50 - Train loss: 0.0002 - Val loss: 0.0000 - Val accuracy: 1.0000 - LR: 0.000004
# Epoch 49/50 - Train loss: 0.0001 - Val loss: 0.0001 - Val accuracy: 1.0000 - LR: 0.000002
# Epoch 50/50 - Train loss: 0.0004 - Val loss: 0.0001 - Val accuracy: 1.0000 - LR: 0.000000
#
# Best epoch: 6 - Best val accuracy: 1.0000 - Best val loss: 0.0039
#
# OR_orthogonal -> ['IR', 'Ball', 'OR_centred', 'OR_opposite']: 0.38
#
#
# Epoch 1/50 - Train loss: 0.3122 - Val loss: 0.0134 - Val accuracy: 1.0000 - LR: 0.000098
# Epoch 2/50 - Train loss: 0.0075 - Val loss: 0.0025 - Val accuracy: 1.0000 - LR: 0.000096
# Epoch 3/50 - Train loss: 0.0027 - Val loss: 0.0012 - Val accuracy: 1.0000 - LR: 0.000094
# Epoch 4/50 - Train loss: 0.0017 - Val loss: 0.0007 - Val accuracy: 1.0000 - LR: 0.000092
# Epoch 5/50 - Train loss: 0.0011 - Val loss: 0.0004 - Val accuracy: 1.0000 - LR: 0.000090
# Epoch 6/50 - Train loss: 0.0007 - Val loss: 0.0003 - Val accuracy: 1.0000 - LR: 0.000088
# Epoch 7/50 - Train loss: 0.0006 - Val loss: 0.0002 - Val accuracy: 1.0000 - LR: 0.000086
# Epoch 8/50 - Train loss: 0.0004 - Val loss: 0.0002 - Val accuracy: 1.0000 - LR: 0.000084
# Epoch 9/50 - Train loss: 0.0003 - Val loss: 0.0002 - Val accuracy: 1.0000 - LR: 0.000082
# Epoch 10/50 - Train loss: 0.0003 - Val loss: 0.0001 - Val accuracy: 1.0000 - LR: 0.000080
# Epoch 11/50 - Train loss: 0.0003 - Val loss: 0.0001 - Val accuracy: 1.0000 - LR: 0.000078
# Epoch 12/50 - Train loss: 0.0002 - Val loss: 0.0001 - Val accuracy: 1.0000 - LR: 0.000076
# Epoch 13/50 - Train loss: 0.0036 - Val loss: 0.0001 - Val accuracy: 1.0000 - LR: 0.000074
# Epoch 14/50 - Train loss: 0.0029 - Val loss: 0.0001 - Val accuracy: 1.0000 - LR: 0.000072
# Epoch 15/50 - Train loss: 0.0001 - Val loss: 0.0001 - Val accuracy: 1.0000 - LR: 0.000070
# Epoch 16/50 - Train loss: 0.0001 - Val loss: 0.0000 - Val accuracy: 1.0000 - LR: 0.000068
# Epoch 17/50 - Train loss: 0.0001 - Val loss: 0.0000 - Val accuracy: 1.0000 - LR: 0.000066
# Epoch 18/50 - Train loss: 0.0001 - Val loss: 0.0000 - Val accuracy: 1.0000 - LR: 0.000064
# Epoch 19/50 - Train loss: 0.0001 - Val loss: 0.0000 - Val accuracy: 1.0000 - LR: 0.000062
# Epoch 20/50 - Train loss: 0.0001 - Val loss: 0.0000 - Val accuracy: 1.0000 - LR: 0.000060
# Epoch 21/50 - Train loss: 0.0001 - Val loss: 0.0000 - Val accuracy: 1.0000 - LR: 0.000058
# Epoch 22/50 - Train loss: 0.0001 - Val loss: 0.0000 - Val accuracy: 1.0000 - LR: 0.000056
# Epoch 23/50 - Train loss: 0.0001 - Val loss: 0.0000 - Val accuracy: 1.0000 - LR: 0.000054
# Epoch 24/50 - Train loss: 0.0001 - Val loss: 0.0000 - Val accuracy: 1.0000 - LR: 0.000052
# Epoch 25/50 - Train loss: 0.0001 - Val loss: 0.0000 - Val accuracy: 1.0000 - LR: 0.000050
# Epoch 26/50 - Train loss: 0.0001 - Val loss: 0.0000 - Val accuracy: 1.0000 - LR: 0.000048
# Epoch 27/50 - Train loss: 0.0001 - Val loss: 0.0000 - Val accuracy: 1.0000 - LR: 0.000046
# Epoch 28/50 - Train loss: 0.0000 - Val loss: 0.0000 - Val accuracy: 1.0000 - LR: 0.000044
# Epoch 29/50 - Train loss: 0.0000 - Val loss: 0.0000 - Val accuracy: 1.0000 - LR: 0.000042
# Epoch 30/50 - Train loss: 0.0001 - Val loss: 0.0000 - Val accuracy: 1.0000 - LR: 0.000040
# Epoch 31/50 - Train loss: 0.0000 - Val loss: 0.0000 - Val accuracy: 1.0000 - LR: 0.000038
# Epoch 32/50 - Train loss: 0.0000 - Val loss: 0.0000 - Val accuracy: 1.0000 - LR: 0.000036
# Epoch 33/50 - Train loss: 0.0001 - Val loss: 0.0000 - Val accuracy: 1.0000 - LR: 0.000034
# Epoch 34/50 - Train loss: 0.0000 - Val loss: 0.0000 - Val accuracy: 1.0000 - LR: 0.000032
# Epoch 35/50 - Train loss: 0.0001 - Val loss: 0.0000 - Val accuracy: 1.0000 - LR: 0.000030
# Epoch 36/50 - Train loss: 0.0000 - Val loss: 0.0000 - Val accuracy: 1.0000 - LR: 0.000028
# Epoch 37/50 - Train loss: 0.0000 - Val loss: 0.0000 - Val accuracy: 1.0000 - LR: 0.000026
# Epoch 38/50 - Train loss: 0.0006 - Val loss: 0.0000 - Val accuracy: 1.0000 - LR: 0.000024
# Epoch 39/50 - Train loss: 0.0002 - Val loss: 0.0000 - Val accuracy: 1.0000 - LR: 0.000022
# Epoch 40/50 - Train loss: 0.0001 - Val loss: 0.0000 - Val accuracy: 1.0000 - LR: 0.000020
# Epoch 41/50 - Train loss: 0.0000 - Val loss: 0.0000 - Val accuracy: 1.0000 - LR: 0.000018
# Epoch 42/50 - Train loss: 0.0000 - Val loss: 0.0000 - Val accuracy: 1.0000 - LR: 0.000016
# Epoch 43/50 - Train loss: 0.0000 - Val loss: 0.0000 - Val accuracy: 1.0000 - LR: 0.000014
# Epoch 44/50 - Train loss: 0.0000 - Val loss: 0.0000 - Val accuracy: 1.0000 - LR: 0.000012
# Epoch 45/50 - Train loss: 0.0000 - Val loss: 0.0000 - Val accuracy: 1.0000 - LR: 0.000010
# Epoch 46/50 - Train loss: 0.0000 - Val loss: 0.0000 - Val accuracy: 1.0000 - LR: 0.000008
# Epoch 47/50 - Train loss: 0.0001 - Val loss: 0.0000 - Val accuracy: 1.0000 - LR: 0.000006
# Epoch 48/50 - Train loss: 0.0000 - Val loss: 0.0000 - Val accuracy: 1.0000 - LR: 0.000004
# Epoch 49/50 - Train loss: 0.0000 - Val loss: 0.0000 - Val accuracy: 1.0000 - LR: 0.000002
# Epoch 50/50 - Train loss: 0.0000 - Val loss: 0.0000 - Val accuracy: 1.0000 - LR: 0.000000
#
# Best epoch: 1 - Best val accuracy: 1.0000 - Best val loss: 0.0134
#
# OR_opposite -> ['IR', 'Ball', 'OR_centred', 'OR_orthogonal']: 0.41
#
#
# Mean accuracy: 0.37
